# 6   UUOmcA3f_RrH6b9NmcNa4tdg
# 7   UUq-Fj5jknLsUf-MWSy4_brA
# 8   UUYPvAwZP8pZhSMW8qs7cVCw
# 9   UUsooa4yRKGN_zEE8iknghZA
# 10  UUJ24N4O0bP7LGLBDvye7oCA
# 11  UUFKE7WVJfvaHW5q283SxchA
# 12  UUsTcErHg8oDvUnTzoqsYeNw
# 13  UULXo7UDZvByw2ixzpQCufnA
# 14  UUupvZG-5ko_eiXAupbDfxWw
# 15  UUvC4D8onUfXzvjTOM-dBfEA
# 16  UUXuqSBlHAE6Xw-yeJA0Tunw
# 17  UUOpcACMWblDls9Z6GERVi1A
# 18  UUX6b17PVsYBQ0ip5gyeme-Q
# 19  UUb-xXZ7ltTvrh9C6DgB9H-Q
# 20  UUBi2mrWuNuyYy4gbM6fU18Q
# 21  UUq2E1mIwUKMWzCA4liA_XGQ

# %%
video_ids = []

# Getting the video ids from the channel's upload playlist
for channel_id in channel_data['playlist_id']:
    request = youtube.playlistItems().list(
                        part='snippet',
                        playlistId = channel_id,
                        maxResults = 50
                        )
    response = request.execute()
            
    for i in range(len(response['items'])):
        video_ids.append(response['items'][i]['snippet']['resourceId']['videoId'])

# %%
def get_video_details(youtube, video_ids):
    all_video_stats = []
    
    for i in range(0, len(video_ids), 50):  # YouTube API allows max 50 videos per request
        request = youtube.videos().list(
            part="snippet,statistics",
            id=",".join(video_ids[i:i+50])
        )
        response = request.execute()

        for video in response.get("items", []):  # Prevent KeyError if 'items' is missing
            video_stats = dict(
                Title=video["snippet"]["title"],
                Published_date=video["snippet"]["publishedAt"],
                Views=video["statistics"].get("viewCount", 0),  # .get() to handle missing data
                Likes=video["statistics"].get("likeCount", 0),
                Categories = video["snippet"]["categoryId"],
                Comments=video["statistics"].get("commentCount", 0)  # Removed 'dislikeCount'
            )
            all_video_stats.append(video_stats)
    
    return all_video_stats

# %%
video_details = get_video_details(youtube, video_ids)

video_data = pd.DataFrame(video_details)

video_data.head(100)
# Out:
#                                                 Title        Published_date  \
# 0              Why Toll Text Scams Are Out Of Control  2025-03-15T16:00:45Z
# 1   How Americans Will Pay For Trump's Canadian Ta...  2025-03-14T16:05:14Z
# 2   What Trump's $5 Million 'Gold Card' Visa Means...  2025-03-13T16:00:08Z
# 3    Why Aluminum Tariffs May Be Pricey For Americans  2025-03-12T16:00:26Z
# 4   Why Estée Lauder Is Spending $1.5 Billion On A...  2025-03-11T16:00:10Z
# ..                                                ...                   ...
# 95          The beginning of the end for Jimmy Fallon  2025-03-09T20:00:15Z
# 96  Mommy vloggers force their kids to FAKE IT @Th...  2025-03-09T01:00:44Z
# 97  Gen Z is MORE pro-marriage than most people th...  2025-03-08T22:00:05Z
# 98  Trump Wins, Hollywood Whines, and Casey Anthon...  2025-03-08T20:00:11Z
# 99                Democrats post a CRINGE viral video  2025-03-08T16:00:29Z
#
#      Views  Likes Categories Comments
# 0   196740   3218         25      598
# 1   355344   3348         25     3328
# 2   105111   1303         25      501
# 3   602928   7123         25     2297
# 4    76506   1173         25      144
# ..     ...    ...        ...      ...
# 95  102078   7303         25      122
# 96   59412   4303         25      162
# 97   52963   2848         25      271
# 98  118566   4210         25      511
# 99  113417  11160         25     1244
#
# [100 rows x 6 columns]

# %%
categories = video_data['Categories']

cat_data = []
for i in categories:
    request = youtube.videoCategories().list(
      part = 'snippet',
      id = i
   )

    response = request.execute()
    
    for vid in response.get('items',[]):
       cat_data.append(vid['snippet']['title'])
res = pd.DataFrame(cat_data)

# %%
video_data['Category'] = res
video_data.drop('Categories',axis=1,inplace=True)
video_data.to_csv('youtube_data.csv')

# %%
channel_data['Subscribers'] = pd.to_numeric(channel_data['Subscribers'])
channel_data['Views'] = pd.to_numeric(channel_data['Views'])
channel_data['Total_videos'] = pd.to_numeric(channel_data['Total_videos'])
channel_data.dtypes
# Out:
# Channel_name    object
# Subscribers      int64
# Views            int64
# Total_videos     int64
# playlist_id     object
# dtype: object

# %%
df = pd.DataFrame(channel_data)

# %%
import numpy as np

res = pd.DataFrame({'category':['U.S. NEWS', 'COMEDY', 'PARENTING', 'WORLD NEWS', 'CULTURE & ARTS', 'TECH',
 'SPORTS', 'ENTERTAINMENT' ,'POLITICS', 'WEIRD NEWS', 'ENVIRONMENT',
 'EDUCATION' ,'CRIME', 'SCIENCE', 'WELLNESS', 'BUSINESS' ,'STYLE & BEAUTY',
 'FOOD & DRINK' ,'MEDIA' ,'QUEER VOICES' ,'HOME & LIVING' ,'WOMEN',
 'BLACK VOICES' ,'TRAVEL', 'MONEY', 'RELIGION' ,'LATINO VOICES', 'IMPACT',
 'WEDDINGS', 'COLLEGE', 'PARENTS' ,'ARTS & CULTURE', 'STYLE', 'GREEN', 'TASTE',
 'HEALTHY LIVING', 'THE WORLDPOST', 'GOOD NEWS', 'WORLDPOST', 'FIFTY', 'ARTS',
 'DIVORCE']})
print(res)
# Out:
#           category
# 0        U.S. NEWS
# 1           COMEDY
# 2        PARENTING
# 3       WORLD NEWS
# 4   CULTURE & ARTS
# 5             TECH
# 6           SPORTS
# 7    ENTERTAINMENT
# 8         POLITICS
# 9       WEIRD NEWS
# 10     ENVIRONMENT
# 11       EDUCATION
# 12           CRIME
# 13         SCIENCE
# 14        WELLNESS
# 15        BUSINESS
# 16  STYLE & BEAUTY
# 17    FOOD & DRINK
# 18           MEDIA
# 19    QUEER VOICES
# 20   HOME & LIVING
# 21           WOMEN
# 22    BLACK VOICES
# 23          TRAVEL
# 24           MONEY
# 25        RELIGION
# 26   LATINO VOICES
# 27          IMPACT
# 28        WEDDINGS
# 29         COLLEGE
# 30         PARENTS
# 31  ARTS & CULTURE
# 32           STYLE
# 33           GREEN
# 34           TASTE
# 35  HEALTHY LIVING
# 36   THE WORLDPOST
# 37       GOOD NEWS
# 38       WORLDPOST
# 39           FIFTY
# 40            ARTS
# 41         DIVORCE

# %% [markdown]
# ## Function to get video ids

# %%
channel_data

# %%
def get_video_ids(youtube, playlist_id):
    """
    Fetch all video IDs from a given YouTube playlist.
    
    :param youtube: The YouTube API client object
    :param playlist_id: The playlist ID to fetch videos from
    :return: A list of video IDs
    """
    video_ids = []
    next_page_token = None  # Initialize page token

    while True:
        # Request videos from the playlist
        request = youtube.playlistItems().list(
            part="contentDetails",
            playlistId=playlist_id,
            maxResults=50,
            pageToken=next_page_token  # Handles pagination
        )
        response = request.execute()

        # Extract video IDs
        video_ids.extend(item['contentDetails']['videoId'] for item in response['items'])

        # Get next page token (if any)
        next_page_token = response.get('nextPageToken')

        if not next_page_token:
            break  # Exit when there are no more videos

    return video_ids

# %%
channel_videos = {}

# Iterate through all rows in channel_data
for index, row in channel_data.iterrows():
    playlist_id = row['playlist_id']
    channel_name = row['Channel_name']
    
    # Fetch video IDs for the current playlist
    video_ids = get_video_ids(youtube, playlist_id)
    
    # Store the result in the dictionary
    channel_videos[channel_name] = video_ids

# Print or use channel_videos as needed
channel_videos
# Out:
# {'CNBC': ['g-gAepaVU8c',
#   'sXTVwtmABXM',
#   '7W5kGtkU8cU',
#   'QhUjwQnwtcU',
#   '9_tVyeR9oNg',
#   '58mNlQX5AhE',
#   'GGNkHrNlIoI',
#   '8S7dfWGHmRU',
#   '_dg3N_JPiuY',
#   'ZZTJ8idBFVw',
#   'nnne0kilsWs',
#   'AHtEnhEMvpU',
#   'XDpbiK3sdNY',
#   'n_J-SadyhJ4',
#   'TRm3R5RGwlo',
#   'KYY_eHLnz0g',
#   '7hZ0nhb2KFY',
#   'wuIkaDNcuYk',
#   'F8t5p-kK3Ks',
#   'JIjJtyRjiOI',
#   '1Oww8gIbZ0w',
#   'TOPrY7YqBZA',
#   'BzgUOKFrHcA',
#   'WgJPDln3vUw',
#   'gMXwMtS6cIc',
#   '1l1LsEziPAU',
#   'Ny7iOd2sCV4',
#   'dSIjejyJ87k',
#   'UhGNJUCfxgk',
#   'H9OmY-Tgup0',
#   'OEh7AA7ZP8U',
#   'egD1ZoRrpVw',
#   'r3SnoTw3Sv0',
#   'p18BzD5Fs9E',
#   '2t0S0iKlAis',
#   'Vq6Fw03x1fk',
#   'uYY_ytPi83E',
#   'f4nZRqsB8wA',
#   'vrENPDN9ZMI',
#   'X_VquKOKKPY',
#   '4LJWfVSxfAk',
#   'h5P8WHBrQvo',
#   'LTZlGXZlIgQ',
#   'PKdL5NPbg7I',
#   'MmTYYsn82-c',
#   'dNQSb_yGSUU',
#   'klEgakT56c0',
#   'R8OvuRPeYgk',
#   '0d-uc8p5GrE',
#   'WEBiebbeNCA',
#   '__rs-XJYnAg',
#   '-9ruout30tg',
#   'LryZ79zHUgs',
#   'qijlvlJ3O6A',
#   'Kbk1QyS0B_0',
#   'bk-oTa4p4Fc',
#   'rWFVGUx6lko',
#   '3YWEy0ijeuo',
#   '6BZVucAbcQo',
#   '7irBlvFs2V8',
#   'i0Z6u125PZg',
#   'zio8-WF2gGY',
#   'CKveIB4uE2U',
#   'p2f8-nMNpMQ',
#   'LNvpyNhmJZ8',
#   'gmPlewWsb0E',
#   '9hcN7nmORPE',
#   'ZKcxHz9E2lo',
#   'KomDkj5scsg',
#   '22StbCBvWLg',
#   'Y97-OQjhhU4',
#   'qZVyp0FZBY8',
#   'QupW_9gSNsE',
#   'R47vVwAp5yY',
#   '58zHJL1dKtw',
#   '2rAn-gmBMEI',
#   'PmpNSH3-dUA',
#   '45UAmy9pet4',
#   'UT6C93PM61I',
#   'jUzNEoI9PpE',
#   '-lBjt8W0GQk',
#   'YKuoq38rqHw',
#   'mJG4MdepNSA',
#   'Dtdt8ZCTCFs',
#   'q0ibkjyvpDg',
#   'WHat_LYrpQE',
#   'cUa50XwO9oc',
#   's36eG_ZHmGA',
#   'BrNu2a9uhR0',
#   'mXPMXVLs3-Q',
#   'J1GIF6VNipE',
#   'inCPDI_HqOw',
#   'S-y1V-27Gk4',
#   'KPd-zOdln04',
#   'mIvMIweg90Q',
#   'LVGkqHMisVo',
#   'y_HPF-bFiA8',
#   'Zl1Tp38oxYk',
#   'P8ExkUxgYw0',
#   'tEU69DLFmH0',
#   'JV5bDK0G9FU',
#   '1gzyx2S8U2E',
#   'sDItVG2n1bg',
#   'CFcQOSzetOs',
#   '6oIGdgRIqrI',
#   'BSTtx3jiZDA',
#   'qTS_jRCUzEs',
#   'LMUWTDRfWDs',
#   'MUJ-u7kpwoM',
#   'PXvcwM977D0',
#   '3G-vTV9SVW4',
#   '4buXNWw-a-I',
#   'IZ6CZAOpw3E',
#   '74EgRT7cjMA',
#   '_hMWcyJ945o',
#   'MYXMQnJpa_M',
#   'esQ4MFG8EHs',
#   'Lp9VqJ79QcQ',
#   '8hJhRj77Gy4',
#   'xOTFXVgI3Sw',
#   'kt5s4thhRIg',
#   'K5pvsCztjNY',
#   'M5a_z6wCAyw',
#   '0KaOX4BBJGg',
#   'r5m1vr9Sap4',
#   '5i3Y14TNqCI',
#   'SfemdDpQBRQ',
#   '95kcrgRhvK8',
#   'KUt6ktzSEVc',
#   'VeDT9czFLtM',
#   'xMUj1_SL5_E',
#   'o_7XarmoDIw',
#   'Uj8V_wVr_qw',
#   'Sesb6tJ4c7c',
#   'M7TPrt2RcL8',
#   'ZQ7QDH8vC-o',
#   'aQIcgmz2ang',
#   'WaEdUjfs4xI',
#   'KfAPQ50V_ac',
#   'kphgNAivs9Y',
#   'Ym5pOLjsG-I',
#   'W9ABl-frlAk',
#   'uvlJvqwNGuc',
#   'Vc8nvUkKH4Y',
#   '8Sg4D4EWUUw',
#   'Ocaimh0SHOY',
#   'kka3D6ePZa4',
#   'uOIPmQrrgnQ',
#   'l9zFZtymi-0',
#   'hMXUY-mH3-c',
#   'jMrA6SiR9NA',
#   'ODG59UjBiGg',
#   'xxOOpWWr6QQ',
#   'AEdkq94pJmQ',
#   'rYzzUZGCTrQ',
#   '0d0yCebRVWM',
#   'rVDE5Q74EhM',
#   '7HgT-CBmKyE',
#   'ur2Wr7eoW9Q',
#   'bgusip5nlGg',
#   'UuMjjIjX8_8',
#   'wPUB0fmnOi4',
#   'X5xSreFNteU',
#   'tu5OKYXe3Do',
#   'XzkrDnVUKjw',
#   'elTRh5fi01k',
#   'Il_2vg75NR4',
#   '4WywwDmY66A',
#   '0zDlJwczDSs',
#   'EacCAYDgSPo',
#   '_Js4R-kBtpY',
#   'UczALD7ZZDU',
#   '9jwXZhXi-TA',
#   'jxyxRjplEq8',
#   '6-un6TzvTmM',
#   'nyOD7m4uOv8',
#   'PhfYARIpF6Y',
#   'MucuOtJtqnM',
#   '-FAYkoAeTVU',
#   'Zp9E3Xaf4gA',
#   'pzqJRGGOWc0',
#   'TbscHpEpg6s',
#   'mcMNXNhhBuE',
#   'N_WQKJXBgqU',
#   '0iJQjFo09JM',
#   '9DLwtGw5yZY',
#   'w2AZn3RauW8',
#   '2q_yVneczCE',
#   'VdACzw_D6pY',
#   '5dfm6U53DMc',
#   'uqw7Pte--PQ',
#   'ZAhRuuNG_BY',
#   '7dCfvhvX3K0',
#   'j-BKmFVCM3s',
#   'Wr7YVVF_9Uk',
#   '206xGiC-IYs',
#   'J4kWugbH4qo',
#   'uszPx4S6yes',
#   '8VWPqU2yR8g',
#   'MJQIQJYxey4',
#   'FGeM6jLsC5g',
#   'WveQVk9rd4A',
#   'Iaxh17AIsng',
#   '96VqhMGCwss',
#   'HpAdssntCiM',
#   'Vyf980e-4E4',
#   'qoEtGstNYtM',
#   'BsXs5V6LKp8',
#   'zZOuU05hxtE',
#   'Rwkh7F1siEE',
#   'npg0AP4r5_E',
#   'GqWw8-TdjXU',
#   'pfB32FkAxh0',
#   'v0uKLCZocjs',
#   'ZFmapxYBafY',
#   'yuq0bU53SLo',
#   'NORkGCx4nGg',
#   'LsrpTcS2JUk',
#   'hCvs3ZmBkVk',
#   'j9i6vhVDXDc',
#   'frKtMYlcYKo',
#   'Q5rGCvVTySc',
#   'Q4_YTXhq7no',
#   'TaB-JPlzELo',
#   '0QpCUz2nyOk',
#   'TG691vUlUZs',
#   'IycQh-DFvnU',
#   'Dnz4AuzW9Uw',
#   'hYqWBcGG2QM',
#   'RvAQmEJJAFI',
#   'ICllQ1zC0Qo',
#   'YOx216YV16s',
#   '42Jt5IBNPd8',
#   'Tye2AoTCDwk',
#   'M84SAxJNHIc',
#   'kr2tTST94y4',
#   'W7pJHSV5Bp4',
#   '7s4QX2H-3GI',
#   'd6mHBLMtbQM',
#   'flKeJViSgbA',
#   'M-nXZCxzKho',
#   'MsCGme9epBQ',
#   'MOreJAyfUUU',
#   'oBfLN1Xv7es',
#   '6Hh43yF_98Q',
#   'N2cb14CbVCA',
#   '7kUJhWUm3JA',
#   'mKG961m0sAg',
#   'g8Nar1s5UgM',
#   '5myGiqMJ6PE',
#   'pBiI_x5lZoA',
#   '47DsSN6F7eQ',
#   'tJwVoma8ZVk',
#   'VgcmwQxt3XY',
#   'Y2O68uKGbR0',
#   '6YD8T8gqmeU',
#   '4ZLxHc96IAc',
#   'KxxW9grVDfs',
#   'jRTmpM7ZVTQ',
#   'C4o_Jx4UZi0',
#   'XeBmanpy4oc',
#   'BlrhwfA4uUg',
#   'LWJCRzoRADU',
#   'gXPRCnPJYbY',
#   'BJVVDYD65a4',
#   'CHdOnJhr6mY',
#   'XZemo1KVQMA',
#   'qPX62kKmkpQ',
#   'D_jamDXYGmc',
#   'LiamzUP6rjo',
#   'SKy_gqbZaSA',
#   '8PTovCIa4c8',
#   'GvO4Kr8TNBs',
#   'O4qOE1U9I8o',
#   'Z8mU36xhnY4',
#   '8BfG20F2I3E',
#   'hSWA0O1JUw0',
#   'wDDjDMycdAY',
#   '9e_cbl2BfMA',
#   'BCvqmrPl1pE',
#   'ijkTBtBWJWs',
#   'B47B35egnf4',
#   'ymtfDiMsz0E',
#   'X0Ur7duId_Q',
#   'dcs6t2c3km8',
#   'o3zyH-VHMxI',
#   '2o2F1Y5YXjI',
#   'VsDGIjgj9WI',
#   'k5abCDqzdhM',
#   'W6twlTqthno',
#   'G4d5yV2BXdI',
#   'ntctAxrSkuE',
#   '5aOkIauvsow',
#   'pPZxSJu3oUI',
#   'poXomSdk_J0',
#   'ZDCFw4ZKshE',
#   'O34Ku8rcrvs',
#   'k4CKB-db4XM',
#   'QwSyFMrtvbE',
#   '6cCkimumA6Y',
#   'otCYl7_uU8Y',
#   'R_J_T7TWbXY',
#   '2ucg8Vzm25E',
#   'Gwy6aJ48L5c',
#   'Ym3W_G_oLYw',
#   '4GACM-IZsZ4',
#   'likYxe_Wid4',
#   'dfmEYpCHfCg',
#   'ybl8IvhGAJ4',
#   'Jc7WLFfQikM',
#   '0k1iWaTIy1E',
#   '3gwH-I2d5p8',
#   'M0sTwRs8A_w',
#   'F6TjtgJNki4',
#   'oU5w4Hd1DLw',
#   'xkRv2M--uzs',
#   'FcP0mzWFCQU',
#   'eqVv61px6Kw',
#   'oJMtF7VjucM',
#   'lcF257VjFa8',
#   'gGMXHEDr6gA',
#   'PqCo85OJLpc',
#   'Ef0eOk9ZgEk',
#   'd1QwYdW2Pa0',
#   '0fEN-oWgI8U',
#   '-LNCzJGcJ04',
#   'QtXeiu3PV7Q',
#   'pEVYK6vVS5M',
#   'oDFS6gfDV7k',
#   'HiYeHqYx3lE',
#   'OdZYmiz0e5o',
#   '5MpBw6Mu26Q',
#   'OWZ9HgLckrQ',
#   'bJwLjpcq7uw',
#   '4-6wZtU3wj4',
#   'O5w9rTvlgTM',
#   'SkAc2P_audc',
#   'IbmFN8MrEZQ',
#   '3kXkUaSWlYw',
#   'piEU2gZaL5Q',
#   'In7lWii2-8k',
#   'W8zB-YLW1Fg',
#   'R5DbRyeZNRk',
#   'YhANWIaAl7k',
#   '56ptSZ1kmsc',
#   'N1cPnFUjXg4',
#   '5vVGF9S-NU8',
#   'WXqXzN8Zh2Q',
#   'GNktc1Ppi6A',
#   'Pzg7aN0SOVM',
#   '4OZZ_R1d01Y',
#   '0-aLHi7RCHY',
#   '6-F5XgVxizE',
#   'xw8fpEpwMzA',
#   'VkDmfvIJYPw',
#   'NrJR9CumsXM',
#   'hHaDrM8EgYg',
#   't9DNBxpvxs0',
#   'STjQyl7Kr2s',
#   'pY90kZJeDeY',
#   'yFCozz7v2rI',
#   '8oPXtfZlsto',
#   'EwsLgpVoUOc',
#   'dAp7Ud6hN2s',
#   '53a0Y2xPrTQ',
#   'LQDSs1pebGo',
#   'jAKODOq0omY',
#   'oNirZJqFMzg',
#   'wSxacSDK4Rc',
#   'To8KybI_nLo',
#   '3c9tWFL-wgE',
#   'fO-qr4G6E1o',
#   'Nt0vSRUfC1w',
#   '1V-N2SICguo',
#   'PkB9UAx2fuI',
#   'nXyot2gnxqg',
#   'w5gh341jA9k',
#   'ZbqHWvpCFC8',
#   'Zs4Htc8lqM0',
#   '6xXGmWynKcY',
#   'dbwHnkaUVC0',
#   'cTFu2xtqnKQ',
#   'opcSfNZqOqg',
#   '_QP9HESt3nc',
#   '33I88kBR9yM',
#   'S-E64Ywv1w4',
#   'ccZGxt-ife8',
#   'bD6UZb3lM1w',
#   'yu-nOLiKi_8',
#   'W5XZ_gJBnns',
#   'UfbkvUXTV_I',
#   'QHVAERH4yzc',
#   'y1L18vH8v5E',
#   'TgV--DqLd_Y',
#   'tF0ydkD-qis',
#   'GdYa6VpZ27E',
#   'UBhR-4oxwVI',
#   'RKcqyGPzb6s',
#   'Y3wKd24iqHw',
#   'sw7erXfTV9U',
#   '9BSCzWWCbFI',
#   'b6PNc8xzEus',
#   'Ao7fbajRSKI',
#   'PVBjjMCWBTs',
#   'bzvMqETJNXY',
#   'xbzbXEO10yY',
#   '2eofnM-G2wE',
#   '-VbiHC4gsTE',
#   'cm9qTDZ_MJM',
#   'vGZGohBaRAY',
#   'R5hP0uxsTvY',
#   '7dArIR4OKys',
#   'H5Oom5Rjp_Y',
#   'X_TlXpy-37o',
#   '3R_XbZCJ39Y',
#   '6HOF8bC8vVg',
#   'UdhWvg5mycY',
#   'DtKbc1XWJXY',
#   'NYIEBquIhCg',
#   'F6Rkvs_0xkU',
#   'N8LRBKcK3fs',
#   'jVVU1hecP70',
#   'OFrgzfsEb4g',
#   'g5-se2mD_PQ',
#   'b-Z8ZHHzUHg',
#   'wJVrAkNgKsY',
#   'xptUVqwX0h0',
#   'kXzWTgG2oJE',
#   'TvElduLh9DA',
#   'fobN_XSOQ5s',
#   'hBY-RS8sxik',
#   'pc_iLCI5RVk',
#   'XEXIy4xWgf8',
#   'C6nOWE8betQ',
#   'isI6O-22cTg',
#   'SVgVzEVeP4Q',
#   'mxpnk6F2EXc',
#   'BSpZQRY-SjE',
#   'RShARqtNwcY',
#   'PBPZaM3X43k',
#   'azAJ0flsdKg',
#   '1lVM5zXKmFo',
#   'jXAy34A6gyU',
#   'H9KCBAbsiWU',
#   'yEv_E5WYfmE',
#   'wYE5pBg-0Jw',
#   'miWLE1yhMG0',
#   'fnLMeotB0c0',
#   'PCivX9A8mOo',
#   'pr3VsjCypBA',
#   '27x8s4jVqNI',
#   '68_lqCVtOdE',
#   'zG_l_7bCR8g',
#   '0wR8yPWZ6uM',
#   'S3geK7xVDQU',
#   'mEgZajtRJmI',
#   '52iCmSFW2Wk',
#   'ptynaaiGVqk',
#   'UHYAvU8tYrg',
#   'ULnC3MxY0dY',
#   '3Nq3ye-QCyM',
#   'cZlsZwcIgpc',
#   'X95nWOJQgZs',
#   'hQpDA_QXxbw',
#   'j_V2Qxpc5jE',
#   '9kW5vm0yj40',
#   'bCta29V1fPE',
#   'wnJzv01jgb8',
#   'rMOBoJ7P1Bg',
#   'cjG_8zFVFAw',
#   '0RN4svE4zk0',
#   'pdB79PKftm8',
#   'Z-o3bXBJo9Q',
#   'wAmNUMdn1p4',
#   'QQZFi9IkxGY',
#   'XqwGt69pDXQ',
#   'wdP_goQU0ZU',
#   'xqJiJmDszQ0',
#   'ATLXPjT4OPI',
#   'pe29xCy2ORY',
#   'Vgsey5V8HoA',
#   '2cy8nNRIhyI',
#   'JHDYf18AYfI',
#   'Y5qQdjzu21U',
#   '_Bh8pdUxfo8',
#   't9GFkilCs_c',
#   '8BWhuVkvQ2k',
#   '7s_JdZuERbU',
#   '3kw3Uasvu_4',
#   'RWiI0uqeY_s',
#   '8uKDnueA6LA',
#   'EOWeZ7ZFU0c',
#   'qypcBJPyF5c',
#   '4cmrECH-suA',
#   'au_NQT0Vil4',
#   'I1w6xzBN7mA',
#   '95wMdS-u2cE',
#   '9yU_bVZqqYk',
#   'ko0mvUcul54',
#   '5slVNMFT0_g',
#   'kM8PUOrSDro',
#   'fl38MPOET7w',
#   '2aD36UakFk4',
#   'U4q4hNevlTA',
#   'JQ4tAVkr41Q',
#   'iK3VEF2woRY',
#   'p8yyNOtJ3kw',
#   'QqXcZ10BztE',
#   'iuGEqnmySvo',
#   'X_g6TfUOuEo',
#   'XkqLCNq7_2U',
#   'mW6pb9V0ico',
#   'tBv0mOfX0zo',
#   'M8esItLD6vg',
#   'qACuAWJRFoA',
#   '-7LquJt4vk4',
#   '1WMoAYr8vT8',
#   '-aO--ly05aI',
#   'OZJv_YGpjeI',
#   '-VD-nEHyPIs',
#   'vCalw2p6Vm8',
#   'TgVtXT5Mqj0',
#   'EYdU1X2p2ro',
#   'wfisB72QPy0',
#   'quGoGgbP-aE',
#   'atORPw-w83I',
#   'rViVFrQg4Hk',
#   'kzE7mw7wh38',
#   'wA7RrJvBzfY',
#   'aNy2WNDc5XY',
#   'JuR8pQqluWY',
#   'wOYVIWod1Bo',
#   '2lzgE4QMRuM',
#   'EX4NliS7114',
#   'bbmHk1p4TRk',
#   'Gn4vptZXF94',
#   'JmD9rohDnjQ',
#   'vhcmaYOhNxA',
#   'P-NF-7miGLo',
#   'h6JJSkMGdZ0',
#   'J064wmGKEZg',
#   'YVTxute2lhA',
#   '93Dt3SzhgPY',
#   'kuNCfkDtPNk',
#   '0nsPGMoXqX0',
#   '2UvgQ4IqFw8',
#   'OJLs_So1KUQ',
#   'LuyHxV1drtY',
#   'fppTadeCzMA',
#   'mDamhO7my9A',
#   '76hFMjt_8bA',
#   'pWzstvXQ7l8',
#   'ZfTFVLNnxLQ',
#   'IfTMARbcYaU',
#   '2BOdJadZflw',
#   'nRgBn_a29nE',
#   'KQoLMyq1G1Q',
#   'a5_Bazvjfb0',
#   '2o5uOPL1NwA',
#   'gAsRvSveOxI',
#   'vJv6WQCDPbI',
#   'Er-YsuYZ3a0',
#   'FvvJtx8ndG8',
#   'uHxBWFTIXWk',
#   'qtjnFwfgMv8',
#   'MCSGFpbYqRc',
#   'SaCg7t9sMZg',
#   'wc5MNTKLnns',
#   'ORtHnYBuoQw',
#   'eK9QWB1OOro',
#   '4HxKVR4PI_s',
#   'jVSx1au8kqU',
#   'PoNgAuY57XQ',
#   'uhLNjbhgc6U',
#   'QPAil1xY42I',
#   '97bQR_ipRwE',
#   'ALmlRh9TeXc',
#   '0ydtETPStEI',
#   'eT0EAJo9lRA',
#   'G1zQIvNSk1w',
#   'Hn-eU-ohWms',
#   'D4qALIvxBws',
#   '-0hVuPzK38A',
#   'rBENl0GVxzA',
#   'JU9tWT1xVxU',
#   'XJdeth9_6jA',
#   '64amGbBbT0w',
#   'UBEjgIyp4FA',
#   'mu7EVOUFS0M',
#   '2uPRvM-v-jk',
#   'XqqR64lgl0Y',
#   '59FLrNTGVMg',
#   'FkiINnPuR_w',
#   '9FDznXX-F7w',
#   'oXr3UgM9SVU',
#   'vW5QWpodbPo',
#   '6TflWLqFGTc',
#   'YXTXNzyOMCk',
#   'ONizdYROsSY',
#   'DjxjAfcu7YU',
#   'EPwQ5mygJ-8',
#   'MQ3gFvb4wiQ',
#   'Qz3IQwbcJgM',
#   'OiRLvUMUDGM',
#   'oIs8J7H1fWY',
#   'nYy1zEHvXZ4',
#   'Ji_lt9WagMA',
#   'bkYx9R2k5pk',
#   'NX8epQF9-h8',
#   'eSm93rME8Rs',
#   'Buv_mijy82E',
#   'bWRy83zJUDc',
#   'yMqbj4Kj-z0',
#   'B_ebhNsPI-Y',
#   'FgHSYHXFfwg',
#   'NBmIFTyiGos',
#   '7M5NY9ru1WQ',
#   'GoKkNckbGGw',
#   'R7x1tjBfsz8',
#   'T2iVaBsaE5s',
#   'RQE56ksVBB4',
#   'IMb5Frr-520',
#   'aycwyFuamZs',
#   'SYjF7iaogRY',
#   'dGoXklMy_Oo',
#   'HSh6EgMwMOY',
#   '2npFHrmUCps',
#   'C1KYRMqv_ZA',
#   's4Dh6gAVV2k',
#   'oue5A-7Hpx4',
#   'a7z3NF7dIdw',
#   'L6tuvSbpKJE',
#   '1WPFLWEVGAI',
#   'v_qXC-1PH4U',
#   '9LtLVNUcnc8',
#   '0onrjSE7Ntw',
#   'LzK2rviPo4c',
#   'Hs4Z0Eyx2XM',
#   'LscylAtY98U',
#   'lyk6f9AeDx0',
#   'SRzVFIEA0mc',
#   'CpUO3JARjAc',
#   'cQKA1ihfNAA',
#   'pKdaYTMGcdg',
#   '-n0qpipalV8',
#   'Il4c_snvLnQ',
#   'dENzYdIsjZg',
#   'xB_A-I0e3Yk',
#   'vj0siYi4h0o',
#   'OUULbkSqPPA',
#   'ZFw-mj6vNyM',
#   'vQe_B0x4iso',
#   '5P7563LCK0E',
#   'qn5QoTjZiP0',
#   'q1Is29IJ-Gc',
#   '7X8UOQGxrVE',
#   'eAHuJI10BZI',
#   'Iqp3zfrk2dk',
#   'bmjde13aGeg',
#   'YftwgSD1i1c',
#   'OWuJV_O8YJA',
#   'q_fMkXHYh6c',
#   'Q5rgua9eOuY',
#   'RFADpAOT3yA',
#   'w8-JvnB3-h8',
#   'HIurjZsWJoc',
#   'btkLV7YH8xA',
#   'oe0t4WXqXE4',
#   '525BOKSoagg',
#   '7tlIXkAqSoE',
#   'ipGdPsYHxos',
#   '_-wjA4XlBl4',
#   'NIvbrZ2BWTg',
#   'HJXr_xWM2Io',
#   'FclSidWwL0E',
#   'ysBWViBCI6c',
#   'ADmatp9CYbc',
#   'ACEN0cqg7MY',
#   'Z9HPOpMkVmk',
#   'SnBu2_l_sZ0',
#   'R_Weh5S1jQc',
#   'OqK_6Nor98U',
#   'UnybkwT2c_w',
#   'oMr5JjEOzkY',
#   'f0MPbulQjyo',
#   'd3L2uPuxOxU',
#   'csgtvKigMR4',
#   'Dr1URsXGWgI',
#   '7KleWiR2-G0',
#   'EphS6UR5psg',
#   'xB6wOXQHfGs',
#   'VPaaIDgMy2g',
#   'dD5ac-e2SO8',
#   'sSvvZtXd2nY',
#   'wY0REtdwqA8',
#   'GAiduOoZKB4',
#   'TnURZAtvmLA',
#   'iLsZlrZIFwU',
#   'UN-O6oNes0I',
#   'cRF8sz5HC6U',
#   'oXAsvg_ZZzk',
#   'ANLV6RXO0kU',
#   'icGTy1X_oic',
#   'xFIvInxydM0',
#   'japfUdlcNvY',
#   'EhHBhm73Gw0',
#   'l-BVM673pDs',
#   'tHyC9ypcWCE',
#   'ycAU__6C9pM',
#   'VKV2K4dwZ9Y',
#   'xTPbDU9EVjo',
#   'DN7mYZB3qMc',
#   'X1VLNM14Vhk',
#   'zeD0w3z-z3s',
#   'o1I_5dEcrVY',
#   'R5I9c8oZHh0',
#   'Y2OFq46-6T0',
#   'WxORB1IMULo',
#   'pOmpqdlVCoo',
#   'aae0RcCH738',
#   'g3ddcu-LLWI',
#   'a6sfZ6an-kw',
#   'FX_aiXBJwY8',
#   'JN53nYuOIjY',
#   'EbLmCRuoW1w',
#   '0d0DiW8bcQc',
#   'B58ZrSNPxGw',
#   'DWWvCPGkvvU',
#   'Nh3mZOKgI3c',
#   '0_3OC2dJ_u4',
#   '1nrufw8BSfQ',
#   'kCQiywN7pH4',
#   'ZTgGAbIIXEo',
#   'PeXpY-p5NsM',
#   'FR1kOI9jFWA',
#   '-8xTVMtkqv4',
#   'hZpqzfOSAjM',
#   'dffUqowalwg',
#   'EXkPhklMlfk',
#   'vXQiTjRvHPo',
#   'oJkQkr3Yy2Q',
#   'R8sdGcJxfA0',
#   '-ioosWOWSxQ',
#   '19ITrZHrPlg',
#   'KCX2l-RXVjk',
#   'TjaeR-Zlc_8',
#   'pu55yLeo02E',
#   '2Tp6jfVb6ao',
#   '6LtvSuVzMlQ',
#   'RYZGJ9kRuuk',
#   '0x7wyPMuAcs',
#   'f2Ku3FRXbIs',
#   'GOSimU3hTKg',
#   '6eMg5qhMNec',
#   'qSYrQ3ElTIU',
#   '-R6cBkza17k',
#   'X8TDh_ZDTFQ',
#   'mu0qOK2vwd8',
#   'cWE8a_Ge4aU',
#   'xNRTjSmfAPg',
#   '_gynGb97rPc',
#   'XzF-TcorvfA',
#   'PbWKHKZYT5c',
#   'EEc3uNhr3iU',
#   'OCGDcT9n5RQ',
#   'wnSSzVjv964',
#   'STEB7niL0yk',
#   'p2crvZDNMnc',
#   '6QKfqt2IRTA',
#   'yrA9f0XfvI0',
#   'RrFaNO3rTaA',
#   'Nd0lOspGfCU',
#   '8-hxd8oG8A8',
#   '6Sz9PJ5BUc4',
#   'Co5UKAiMrjs',
#   'csX7vwO3jeE',
#   '0RRMz3qIetk',
#   'tyWf40MMSwE',
#   'xTH3Nm_Ca1g',
#   'Q1ATjEgjcnA',
#   'tycWtaejktA',
#   'dIqwK44EGE4',
#   'lipmfoi-SUk',
#   'b2vdw2a3xSI',
#   '_gLm0Jo0cnk',
#   'X3qz7LFp3PU',
#   'Pu2vJ3DBpEE',
#   'ZZLDK-7kw1U',
#   'YdbA7Z8Ae4w',
#   'Vyr35KVY0Fo',
#   'yViw8Rh8T1w',
#   'joj4oI_6l90',
#   '0lPImcTymyg',
#   'qr6NHVddYow',
#   'yd2XPJn4VOI',
#   'COkbXnx0MmQ',
#   'arqIJ-Aqa_c',
#   'RMzoCNPctuo',
#   'RgFWmkkkFfg',
#   '8GP1QuQIW7E',
#   '9NyxcX3rhQs',
#   'SIdc-BaD0T0',
#   '6Q95icm9pdY',
#   '7k_7OHt45os',
#   'vtppvJTVLH4',
#   'Q7vbaicfZc4',
#   'czYsgdtZTws',
#   'E8-T_dqhTS0',
#   'J-ONhKDZIHM',
#   'kVknjqEM6c8',
#   'h3WwL93Qp1w',
#   'Hg8KnQEkEW8',
#   'bmRMXt9OOgQ',
#   'N6cyRnL_OfA',
#   'LFYyimOBomU',
#   'ccA-zK_bbwQ',
#   '6lNgLNnfSoQ',
#   'exG0i8Lllfw',
#   '8QsnW-InkrQ',
#   'Fd1i2XB_cus',
#   'd6EXbQ6jqIM',
#   '-2vmhEGx5Xw',
#   '3MCD1nqTIxA',
#   'f9zTwJB47OY',
#   'vX25ZJdvn44',
#   'Tk0CWXGpw6o',
#   '8aVslz2oXoA',
#   'QNa-4LSuN-s',
#   'AuQ2BdrJYI8',
#   'HZPy8hH86LY',
#   'YJqZI67J-iE',
#   'G4FcEWzoCng',
#   'IqZI0ST53ds',
#   'l-6RXnF30w0',
#   'NmevaKKuwEg',
#   '6BCP6eKstVQ',
#   '71OTCw2vHaw',
#   'vS2x74bw0LA',
#   'oWig0BW848o',
#   'Q8LITFMozEg',
#   'qEKKFDP9M3k',
#   'eDeBt-uBJPM',
#   'R-URlDU8AxQ',
#   'yk5KDzBf4FI',
#   'ol3Nw151cJo',
#   'hSkZlmFcy54',
#   'qUJsts5qvoc',
#   'gtvK7TCInNQ',
#   'n5RbNbb0STM',
#   'WvhLGKHHoqw',
#   'GSJUgWgtDpU',
#   '8akjgMluVDI',
#   '959pbjCxEQk',
#   'AiMtcSrE9HA',
#   'M3eXfx4GpJc',
#   '4WcU1MwM9PA',
#   'sCSkNiyYv8g',
#   'MNJkvbgoG3o',
#   'L4BQhipkK_8',
#   'nwW6lGn-Tk4',
#   'iVLiRWD3gAM',
#   'n4z71wElB3I',
#   '2kJDTzFtUr4',
#   'SBVoME8hZ-I',
#   'RNQ2yfyzOi4',
#   'H7S1Oweqto0',
#   'qK2lNUVfmMQ',
#   'Q0kYMxR4hYc',
#   'LBWtsOib4vQ',
#   'XlnspY2wOVw',
#   '2goaglM2Wiw',
#   'cug3YJpF6TY',
#   '4DIKVVY5NbA',
#   'M8XebKpsNZQ',
#   '9O4iMDwUXb8',
#   'knYzcY3Qb64',
#   'OR6RuSTcdHE',
#   '16IHvuPCVpw',
#   '0aA_6BTVyCs',
#   'Zz88goIgOVM',
#   'w2BaPAS5n9w',
#   'D_-9uACGJeo',
#   'nvB242RR31k',
#   'H0dT77lBdL4',
#   'DbO-jg3QHS8',
#   'pgc71l8WmaI',
#   'i8I6waf_1RU',
#   'f60Z4epksOk',
#   'ks2_wY7f-MM',
#   'HKi5Vk-mhK8',
#   'oWtqua_mXTs',
#   'Qk2KqsWkT5g',
#   'GjyWAL5Q27Y',
#   'nB_qqjte52I',
#   'KTjeh5QPL0o',
#   'qtgkIkPcEOE',
#   '-GGVfrc6eNQ',
#   'wCmruTxpkw0',
#   '-I9utJqqU_o',
#   'woZmq6gIZBM',
#   'y2GPQ8adKI0',
#   'tsYvhOuw7u8',
#   'dRvkOFdfW7k',
#   '5vHXvcbGT5k',
#   'EpTTZ1y_dy8',
#   '9dV9Dl4PdMc',
#   'gTZK94-5yjU',
#   'wdAjnpzWlsI',
#   'dT1TXdRG0Do',
#   '5RIjWTO2Yz4',
#   'q917Mp3yerE',
#   'n689owdQFYc',
#   'VhQYdADfCVE',
#   'bEh0Q94Gjss',
#   'QKHAVzCr28M',
#   'NfNgRc4sJt8',
#   'NJhpoYwAqFA',
#   'BJ_7bc1bTCw',
#   'vAL2YtZRiIY',
#   '3VrQRMPuJz0',
#   'ZSUoClnyyN4',
#   'rAcEcb2osi4',
#   'NSkp90XY4P0',
#   '6Z6v7cSXn4k',
#   'rWW-zwnpvjo',
#   'LTyH2J8G0TY',
#   'SlQksI4Y9M8',
#   'C-htC2fK7H0',
#   'pqX1D5AQFfo',
#   'JL4KzBzmt9c',
#   '-IYLMnugVD4',
#   'xANwNonI9aw',
#   '4DCshryz5y8',
#   'cr1M992-LP0',
#   '9bbWYVrQgZ8',
#   'zfZqpdt3Zy0',
#   'eNLC9sYDuV4',
#   '12xYSwfsSj0',
#   'mt3M8Ra3zuA',
#   '6wsv6-PBhwY',
#   'AuPZTlWG-Ic',
#   'hZVgAK0EFIU',
#   'nyvsYOCIplE',
#   'Sj4MnHQMzRQ',
#   '-Vm_gabtIA8',
#   'K6knVq8OfgY',
#   '0l6Q1DMqWho',
#   'bpAwIOO8DSY',
#   'BZd8g1s8Fno',
#   'lUKooQ9TZv8',
#   'SlsBHnOTxgk',
#   'sM7FBBr5yeE',
#   'DKpkL3ZyLBo',
#   'UiHFtubW4JM',
#   '6okaRfROlnY',
#   'AoyHVWgJt3Y',
#   '9lHCJrQOFBA',
#   'gObuL6CcRF0',
#   'TtjhHYi95rQ',
#   'JI7d4xrfUjI',
#   'ZBuds2vCgv4',
#   'A7DC1tg53RE',
#   'zBuabackmJI',
#   '4MzOPf4w8hQ',
#   'C-VjqMZRCTg',
#   'H0Yo3ciV6Kc',
#   'oIB5w3hdU_Q',
#   'iSVHp6CAyQ8',
#   'wgLLPjLZz9o',
#   'E5bacxqobwY',
#   '_tMVYxNRbMA',
#   '_836ZXZcfzY',
#   'xsplrrbdzWo',
#   'iATklZ715H8',
#   'TEpfarXxO7o',
#   '772AMpnpFM8',
#   'qO2d9FpBzDI',
#   'LgXtMtLdDxc',
#   '8NTQ_LUf-JU',
#   'qggFgVYFMl8',
#   'mrbMkSRhiRY',
#   'CM1fL5D1_W8',
#   '5kHcLil3G7Y',
#   'dJAMkoiLYZY',
#   'CnYbGeS5Osc',
#   'Yyfq4lyUNKk',
#   'QRihG16iSug',
#   '7Bo-cjA11Io',
#   '_TCNvDujfR8',
#   'O_EU_Sqj4kU',
#   '6BgScgM1g-g',
#   'mB3mmI5HqDI',
#   'GrS9j7K4M-s',
#   'ddbb2nPwC-c',
#   'jIHzGD5mb5o',
#   'PGTdxR3HAh8',
#   'D_SPymCay18',
#   'JZ5ZpGkGwdE',
#   '2TpZSXWT_2I',
#   '0sj-8pjt9Xk',
#   ...],
#  'Ben Shapiro': ['Xzr4yTLpXUE',
#   'wzVGi75-83Y',
#   'IdbpoaUOaBk',
#   'reE2FxY1P6E',
#   'QWOP7oZDm04',
#   'n46_zEArvac',
#   'MyEfU-V0lAk',
#   'HRh52XtCQZA',
#   'QC6w3JCVOOU',
#   'IQSaKYeHrLg',
#   '32l6pg2mVLU',
#   'nFGtbGaT6oQ',
#   '3V05aheNO7o',
#   'H5_pYvy2dRc',
#   'm_3m2tQ5l6g',
#   '2aGZs-2J01c',
#   'StLeqoGW88w',
#   'PQ5uBndKcLg',
#   'T-gdmBaZKgE',
#   'YB6HNiovghU',
#   'nIz2wHwUmVU',
#   'WWkM278POtM',
#   'mMaFn8oCNgU',
#   'OiACf1brLY8',
#   'f7NPtDBSVIY',
#   '4sjQGI3V9O4',
#   'bo0Ow-4pMwc',
#   '1QAUFPX-c1g',
#   'fGhL7FGb-n0',
#   'UjZSUduKaoc',
#   '-UNYWPcRBr8',
#   'KJDDwckzjE0',
#   'q8mVbkDjjCI',
#   'zlOe2nTdkYc',
#   '4vOsExllqoc',
#   '-h1UxT3RQxQ',
#   '-0OhX9EWrJs',
#   'jTckmpgyC8I',
#   'XZWmJW_i8ps',
#   'm0Qcl5ZCh48',
#   'S_Oq-u7VDew',
#   'Ao3GqTFChnE',
#   '0E65Z-ZmBR8',
#   'et5wV61acRU',
#   'tM6FltxzSWY',
#   'X051r-tpsZk',
#   'qyY5lktjbX4',
#   'ASbmUutPJhk',
#   'QEIfJM24g1g',
#   'TyTk422BE-4',
#   'e7-4xsUvdqg',
#   'ylaoPZmlhBQ',
#   '3h8a-UjnPeQ',
#   'HJpfF3zRxeg',
#   'cJsBvjla3Kc',
#   'U18y534_joA',
#   'HSV0itBg_X0',
#   '96BpfoY7b6k',
#   'UCM8SEigUmY',
#   'yI81xoDBlaI',
#   'uoDPsHHynv0',
#   'ns3m7VIZylw',
#   'gQrKDlLLj6o',
#   'h4I30cGx2BA',
#   'W7f8DkZxsms',
#   'G5VvCe50xU8',
#   'gilp4BW_ZU0',
#   '44FbyxAI-GQ',
#   'hplOd5IhMIc',
#   'By6dSe4Jb1Y',
#   '3HJF4DJ6kJs',
#   'gKIt6EKRALE',
#   'astCamNc-zs',
#   'OtZxCzfihHY',
#   'lIaI209ZUKw',
#   'OOb5Hd4Yn90',
#   'Ozmhx7QD2Ak',
#   'O5Txt0C2bVo',
#   'z3-7KBsBgco',
#   'MzPS2pYrWnY',
#   'AB7w7IBIXz8',
#   'Vd2MXp_-aUo',
#   'YkYAgfdvciA',
#   'HihPSv26m5c',
#   'RjGqcT2nUUM',
#   'qDOFThwbpqk',
#   'TiKVz2rNcww',
#   '6m8WF9wTKpM',
#   'OOtf2V4ZCTs',
#   '8PbWgypAHI0',
#   'h11fFHve8-Q',
#   'Bi0dcEWl1Ms',
#   'vNGad59OziM',
#   '4nZ69lOpP5w',
#   'o1A6UWwheAc',
#   '-abPkK5yrmg',
#   'NDRaIFN1t5c',
#   'neBHJk2fb5M',
#   'ELbCQDvrle8',
#   'U7spkj6EnRw',
#   'B7tXcfjrc8k',
#   'm0QCO97wyzY',
#   'PhalZaI96zA',
#   'f_lxKtGNeCE',
#   'E3IV43DVREs',
#   'm5itHenKbyc',
#   'Zzqg2cqfs4Q',
#   'vquxzuNba8g',
#   'LTwdqRNsFx4',
#   'M_S5MFxJBAs',
#   'Pgo35MFpz4g',
#   'ieWQAqqNhxY',
#   'Vg15KACnat8',
#   'JzsKwlhLa3c',
#   'QUIifGR9lDk',
#   'rDdHsqsHZDI',
#   '-mRqcEiF6PI',
#   'jPu8UG1MxnE',
#   'QwQ72Hg41VU',
#   'pQmJxo4zjOk',
#   'iSQuXlhtVZ0',
#   'YZIyc3Eoaa4',
#   'ydKIV58v-lk',
#   '1BPJsJ3F6Eo',
#   'nVmRA0zRhVU',
#   'V3gGYfPKhJc',
#   'pxuwBPTVaVo',
#   '3eSmkzWfDBA',
#   'baiLqAcdxEY',
#   'iU6UJ2VBSzQ',
#   '7Z11YJsledo',
#   '9Vp0msTs5HA',
#   '7hPoQNFU0-I',
#   'pREp-w6m_vQ',
#   'sw-Ro_9FVzs',
#   'Pry2N4KCSwA',
#   'PKoBzi355KM',
#   'OZ7fi38Wk3I',
#   'OfLrVP4uA6E',
#   '_FjX8elCJyk',
#   '5USB3V0yVUA',
#   'uYYznP5kIZg',
#   'gAoW3M7I-44',
#   'MbShAU6TYvM',
#   '8M9mBO3d0eo',
#   'bYNXRX-reOs',
#   'bPosMfIGxwQ',
#   'JEP4XRHJX8M',
#   'QXp7mTgihNs',
#   '_UYYfP0lo0g',
#   'xM3CWaAACDE',
#   'Wtnj9flzZR4',
#   'vUSrOI8w8YY',
#   'N7M7zf3ePx4',
#   'tidGEnbZevc',
#   'nnEp5TSwp9M',
#   '6L1aYWXfLFE',
#   'sTO4WRrGtk0',
#   'n3zu1YVWA8I',
#   'vcgcx3nme9c',
#   'arO5y_tji_A',
#   'p-1Wvuuua1M',
#   'DvHMzuwYkqE',
#   'gQ8ueDaIT4g',
#   '2KxsbXb2Tds',
#   '72uiDtt2HBM',
#   'ZvLNwhlCuPs',
#   'drcw4STEf8w',
#   '39qtagkJH1A',
#   'FkwTwE9rTME',
#   'zzwIhAq8-TM',
#   'w57SVXXm8VI',
#   'jWQ0W_pxqoI',
#   'F3gch_0DH4M',
#   'xPlOmn-EkTg',
#   'LBdcoAWK-PY',
#   '4PxN4v73za4',
#   'GpAprvtIAnE',
#   'd5gpqeldhNg',
#   'zCdKPMLhXsY',
#   'juOfb5NTakg',
#   '4uDNmaLCzjA',
#   '9jnzQSIlTiU',
#   'E5oY2zCEpl0',
#   'obmhj62IOCA',
#   'SLnhXMBC3jI',
#   'YGcbnBzA8YU',
#   '6z39e2Uc-KU',
#   'Z-IiH4IxKCw',
#   'HijgZLjDigA',
#   '7BX2fBMP45M',
#   'LSwqVGxZaqM',
#   '7gOD3UPERlg',
#   'gY7GGDgUVcE',
#   '7sZ7sMTXn8o',
#   '-2jeEuaDAws',
#   'fhOOLlOthPM',
#   'OZMIFQcwsow',
#   'PsDK_B_z2kk',
#   'nnbpD9tiRoE',
#   '0reiOxk-f6c',
#   '5FVF40-ABNc',
#   'Ji1lMEBgYqk',
#   'dyOrfkMVIk4',
#   'SMXow3avcCc',
#   'XuCc1Sc_bhE',
#   '3pgqcfCWTtk',
#   'zrO-AADgE4I',
#   '48Uw1S231ro',
#   'fwUWJtNoDyE',
#   'Ot6WQrpSyS8',
#   'EjMSHESHfc0',
#   'EEwV-W3F_TY',
#   'ZnJ-s2vrWdE',
#   'Us3q7LJlRiY',
#   'COD5nMK-6UM',
#   'teDQo8MVUk8',
#   'PaxVrCYmi1o',
#   'a4XRCgWGpaM',
#   'lTuArYexO8Y',
#   'G9wNXxXD3RU',
#   'aS5rtLWxE8Q',
#   'p-yXhsS_puA',
#   'AHoxQrV53TY',
#   'xTElMvkD70U',
#   'rjr_-KlZKgQ',
#   'xoxvQK8fJwM',
#   '8jBT1ynCA1k',
#   'AHCfCDLd7To',
#   '3nmB0wX8Gpc',
#   'WOqZiKAUTkU',
#   'BrBC07MLm9M',
#   'EWFwOKM8p7I',
#   '7s5hp6dYbt4',
#   'ObYxKuQjwI4',
#   'cgl1HbgKxsg',
#   'HAwBfYyfG3M',
#   'EOQj6S-pLfw',
#   'zFgr0PnWoYI',
#   'Nbb1xllJCa8',
#   'OCWKLMeeXOQ',
#   'bYGLoQdP1eQ',
#   '6WWwlCqIHQo',
#   'l4qx9CMFlOk',
#   'p6-44fdvfIk',
#   'L31ic5R3vP8',
#   '8p-ZVdtd9uQ',
#   '1_b1E5-5a1M',
#   'Ea8928chiHE',
#   'kjc91uf4yrM',
#   'BjUOCgd4cAU',
#   '285oAanWbh0',
#   'BgjXoopdcBA',
#   'ILZttgANRgc',
#   'L6I6DUy-rWs',
#   '9IOk-V6Nbcg',
#   '-6hmgRT6WOM',
#   'BVPWk3FIYMs',
#   'p1k7vZ6IIO8',
#   'Yn1HwFsLVGc',
#   'fXJ9yVl8NVo',
#   'EtAxzi0k874',
#   '9uM5aOzneJg',
#   'g_3-09uNPmU',
#   '8rV219pH0kA',
#   'gucMoWjCe98',
#   'Uk5mJWMp8Y0',
#   'slTr_uobzig',
#   '87EKX7U6HKs',
#   'dhehqdvNYiM',
#   '2kizL-gyD4Q',
#   'uSD1y-bO0GA',
#   'FnbYBh_G_v4',
#   'bGx_LerHuxY',
#   'Yy5yu33d0js',
#   '1Mj0CSRqxL4',
#   '64v-pShozwQ',
#   'QzPQseV1EU8',
#   'Gd3b7Zvhdl0',
#   'ZwTodR5rD94',
#   '8XnMM0YIIZk',
#   'OV7huE0w5h8',
#   '9EfARnJQC-w',
#   'CKgbJ8GeoR4',
#   'egIj2GprEiQ',
#   'SODwRAtZqhU',
#   'Kr4QKfVfeEY',
#   'Tl0EaUk6VX4',
#   'bPY_QG-bSYU',
#   'xa6VWAwSI9U',
#   'jjGFdnZPMEM',
#   'rwf3Tf3pbtw',
#   'lWogTBu5xA0',
#   'F-9jd7Y1v_Y',
#   'JLi7333Cj2M',
#   'ZF2_JHuItJE',
#   'lE57ZaZS7VU',
#   'bkm3-L9DC_c',
#   'zrmZ-E9-hx0',
#   'NcETDpMv0Ow',
#   'P51HOTse3rc',
#   'pIqLccrSTrg',
#   'OWvuFWip5W4',
#   '6YMVPITPk5Y',
#   'l9JQgEYJNxo',
#   'YN5IfZcdo7s',
#   'leWSbCBzs0c',
#   'p-YwxpRC7UA',
#   'E51yCl4AYW0',
#   'NqRs6GVzFOM',
#   '9nAm8aBdC5w',
#   'LLFACDG0d-0',
#   'tXD1928RMSg',
#   'qZVAEnyJjQc',
#   'WJLuCGFRBgI',
#   'Tb2b5lC5uBU',
#   '2IzmVy5vfIk',
#   'YN9GBykQ4rE',
#   'oqXITwq4Fmc',
#   'uvuEZJwPNDA',
#   'gsqu-1WIHeg',
#   'YZjuT4fxqYA',
#   '3sEJSZNbQWs',
#   'QYLt0hJMldM',
#   'opHHWXVeL28',
#   'EtNr1gYhwHg',
#   'QP55b8eDQr0',
#   'DNyHAYWn_eE',
#   '3s9WKjGvvmI',
#   'JT8qDfxR_vI',
#   'eF1Suuirhls',
#   '0dc2-S7TpHw',
#   '83oeRgP-H4M',
#   '-r3N1fH8xe0',
#   'IwAeHdUzfG0',
#   '6qHo7yxqLw8',
#   '-prORuv0cF0',
#   'YcLzGjDdAKw',
#   't17x6Rf35As',
#   '14da2bK1Fm0',
#   '2MT6nCxnWBQ',
#   'HiWmNgto4AI',
#   'dkZXSL1c3-g',
#   'QCk5-uKslYE',
#   'MEie2qaVNgc',
#   'cUQ7CHYISZY',
#   'BrSA0lNotkU',
#   'UM1r3Dhd9CY',
#   '7EmTKRXMEv0',
#   'kw2MFAXX45w',
#   'ac-8Ls7lz-Y',
#   'N_iYH1lOq9g',
#   'y0rUt-wE3Us',
#   'sSfSYu9UwyA',
#   'ysC-oqltIJk',
#   'ZIr1KQtALUI',
#   'Uy7uWSaziIg',
#   'sIC12TVle-8',
#   'TlBJ8-mkcv4',
#   'KcMrSdWp6qc',
#   'UWbxiH8Hk1o',
#   '2ftmBxFLQpw',
#   'SfjrVTRkfXs',
#   'XMngpJ5Ib2E',
#   'cRf8zCb_VQ8',
#   '1JiyNnnrTpg',
#   'eYJmkh0NNbo',
#   '1qjd07k_lXc',
#   'QYmkOX82Op0',
#   'A6_FI5XzWvI',
#   'jL7ZnsDdAU8',
#   'tHwbxOEydCo',
#   'jkaxi6elVqk',
#   'wGK2S8ArtR4',
#   '2Qsx25t_ubA',
#   'Ts7_85bKFQc',
#   'JqYnBw_TIFs',
#   'kLXy75PD0FQ',
#   '93mky4T95Qo',
#   'oA16UIP8WPI',
#   'jhjSivT8410',
#   '2UBhuEpmi2k',
#   'JRYW7lyoz8w',
#   'kjomGP1v13s',
#   'S5I6jyq04jE',
#   '60c8QWQJTRQ',
#   'OD6NTY71I4s',
#   'arVIdtKyGiM',
#   'unJ5KWmc9mo',
#   'BBVFiHVTzfM',
#   'pNGOKqt1GeA',
#   'HDCZ-epH518',
#   'sNmlooOEU-k',
#   'ZeBfHsmXETU',
#   'iRty3ZAabks',
#   'WDv0_7AZ-iE',
#   'pQhlHaL2KKY',
#   '6R-_OpTLiEg',
#   'WjNRWQjgiRE',
#   'YWF4ukLplJ0',
#   'AXJ-AqhbVx4',
#   'C_JbK3fcN5E',
#   'lkOS6D2KIkI',
#   '4dbBo0Pb0es',
#   'Bma76ZglO44',
#   'aeIquqYjrN4',
#   '_rSH9-7Twd0',
#   '8ZcYcNPJMbg',
#   'RZy5fRlT14c',
#   'OlLPoKwbYxk',
#   'NHhGQFuOemY',
#   'ccMOIHSaigU',
#   'SA6rm2oljdM',
#   'dULjcKQG-OM',
#   'L5Q-1mLaxdU',
#   '7-ScNYZg-sQ',
#   'VlwmloCxwKI',
#   'bKtORKKDnH0',
#   'iiqh0Us0BZU',
#   'nWIydNqvWwc',
#   'ox5OH-RZlwc',
#   '-Zfw_gr9BWA',
#   'NrFTxnWGSj8',
#   'Iux4p5TcabM',
#   'yqyJBP7Te5g',
#   'bSSIrcPCy34',
#   '4Ow3Qbxg6c0',
#   'TNaGKgXQvms',
#   '-sdEBGY3lqE',
#   'oYObUWW776s',
#   'CCEsrFmf4Jw',
#   'RTUtKmcV9Is',
#   '5PdaQPw-YMc',
#   '5PZcoUlk2Gg',
#   'NXmq1WGnOL8',
#   'ndTplA7Zqic',
#   'mFYXvWKAcK8',
#   '9B1azjMGNbw',
#   'o0LSwCcM1nI',
#   'p9REAWoo1MI',
#   'R_cMY1cc3hU',
#   'ZM-Ur_CIZDM',
#   'md1rgpXeDmg',
#   'G31dgIAjHyU',
#   'dAXiSt5jRFw',
#   '9QaWDfTEEMo',
#   '9ZQGik_X_bo',
#   'rMKKQ3lAlJU',
#   'CkESd_YxaYs',
#   'OpxVPhG9bk0',
#   'zQjuNYmuvg4',
#   'hRoGvsPT6KM',
#   'Ua0uvJ2m_iE',
#   'pWBxQhVu4RE',
#   'ACY12MLhAMQ',
#   '7O224abgX_Y',
#   'sfJ1xqqlQ3s',
#   'BuIktfVlgzc',
#   'kImt4zAeLXc',
#   'zakFRqSJIpM',
#   'X4oMf3cvmtQ',
#   'CDI2Zkryxl8',
#   '84FoUPrSjL4',
#   'lZ3L_COw3Cc',
#   '3j3l1HZp430',
#   '4Fq76QSEn_s',
#   'BmAn9KWPlt8',
#   'klmEJyVzZ-I',
#   '-MlZZzrjd74',
#   'Z8_WqyS1fgo',
#   'g_qC2YhiWv4',
#   'cehPjqCy12A',
#   '4Tz9yfZorqs',
#   'BjYIIKIw4OU',
#   'zYO2Rglg-pg',
#   'qBvyajeLgCQ',
#   'pIv6WAHOQHM',
#   'HsMZn9oKpTQ',
#   'TV2fb0B4hsM',
#   'NVl7bp5xeoQ',
#   '2P5V7dU9rJU',
#   'C9y2FCOjuy0',
#   '2fS9vZZwrx8',
#   'a682VwdDtiY',
#   'J5GPWls4-Lc',
#   '6iXFYwoBvv4',
#   'x1JqRb9h0po',
#   'paxYRkKzX8w',
#   '0lMCh8dalHQ',
#   'URiHBlH2gpI',
#   '7RteSLAhmng',
#   'jbHR3NRLMSU',
#   'eieR-uuL-u8',
#   'cNmQIrXVaiY',
#   'p35p9lf3OUI',
#   'uQoDP18ovq0',
#   'uzNRZpj3M3g',
#   '0KP7AscWd_I',
#   'm8KtW6_qBrQ',
#   'd-7YD5NaHAI',
#   'bFaoJkjr1MA',
#   'M_u_5MfuwLs',
#   'vcj4aPA8GrE',
#   'qztc5pNn7J0',
#   'j5Y3pjaX21I',
#   'Uw9fH9xaO9o',
#   'aANLB-9wO_s',
#   '0p6PjIl6c64',
#   'vuwJe8PieH0',
#   '9YEPVXgsJ2w',
#   'hNcQpjGN1rM',
#   'BwIILRlpTkI',
#   'oIcpFFI5AxI',
#   'NKifs9z4aYk',
#   '8Aqm-GfJwz8',
#   'Ji0DUxrCN2k',
#   'y38-g-E973s',
#   'EmAFjzfh0kE',
#   'VED8G6tFw6M',
#   '5pTBo3GcOqc',
#   'eTpH_LSoM-c',
#   'AHtafqy_hyo',
#   'zDiJ06Jw9fY',
#   'KkkPc5rYDgU',
#   'HITIGKzcu28',
#   'XUKqxfwLnOY',
#   'gw8Av0-YESs',
#   'VcuK4Tqgw-s',
#   'z3eUWax0tDM',
#   'dq6gT1GbGRE',
#   'XHiB4Qeg4og',
#   'ickKfOJV2Ok',
#   'fbEH0aBsXSI',
#   '89cWfVVwyMA',
#   '3QBOR1Ax7IU',
#   'ODDJvhKtRSY',
#   '7qOP7iq8skQ',
#   'ikUOOdjNT4U',
#   'uWIfsOjxmb4',
#   'mcEgEguNfyQ',
#   'N39k3_P5eX8',
#   'n9LV6d1FHvk',
#   'ruCkPwqQGYI',
#   'I64pXQbfyXI',
#   '_KkpGFYpFN4',
#   'VUhiBvlB-mA',
#   'gtHfaqxOtZM',
#   'LkrwqjaiPzk',
#   'KFXxLKQ1Z_E',
#   'onYKY_7U2Bc',
#   'kzavxVlggFc',
#   'D88S3niEUV8',
#   'YwhRwtszmD4',
#   'GrRMBhei6Kg',
#   '6s1gxXgzkUE',
#   'EVIz3VZRQi4',
#   'j4MXPxJ81o8',
#   'MXnyd_4yPf0',
#   'yxJiiD4Smyo',
#   'R0-GasoCizc',
#   'xo1PNnTEbno',
#   'NbgpT7MeWn0',
#   'nVYmv9jgJF0',
#   '5gcaG6KEtOM',
#   'eE2JYorFobQ',
#   'fZh-SoGVZXs',
#   'm4KXYd32Eg0',
#   'asM76ftjaeQ',
#   'I4nz141MLdg',
#   '7u3lrM78q7w',
#   'QyK01BAUSk0',
#   'tLE2UPfm8eY',
#   'FmqJNmo6p_g',
#   'x9NhFNMvr5o',
#   'gLXvcehu1O8',
#   'dzGiTliehvs',
#   'm7xKs37rpcI',
#   'jN8ZZEGDP-k',
#   'kOux3JuqV80',
#   'YpHZZjMM-8o',
#   'SGURvCyvo_I',
#   '8zJptdwWR1k',
#   'uEH-xHdRffk',
#   'FqkKuc0wRX4',
#   'k3vJRslNDdk',
#   '9IWsMHzsN0w',
#   'rJ8TQ6S93HY',
#   'CZXnwwVM4nQ',
#   'mmSGHQha5yk',
#   'DptkvwA2fZ4',
#   'P4MsguVwHJY',
#   'mEm79t7VFpU',
#   'fTCNeNUjKDA',
#   'LosSkmz1-8I',
#   'wQ9pL1S1By0',
#   'm-2dMrGvic0',
#   'fbLptuURMoo',
#   '6dqG0_NQKHY',
#   '0WlMTgH85Qw',
#   'djOcv4COL1k',
#   'mB77-2xnyNI',
#   '-W_6vBTZXf4',
#   'MonwfJ4KFOU',
#   'hSiQ5s-Ozwo',
#   'mZYxgVuvK3c',
#   'uKEwfxC4gnc',
#   'ncNTzh8YFyo',
#   'k3n47-kt57E',
#   'v4fhTv2fZPM',
#   'tCUzGvhUBUM',
#   'Gc5t54C8hXw',
#   'gGsqFIR4h3Y',
#   '2gmWjB-4rS8',
#   'xXpXuZTsVhw',
#   'ciicqiahQbU',
#   'vAthBDdLFsQ',
#   '9dZGxaK-hbw',
#   'gKmuqf54_Lc',
#   '5IKJvvn1xJg',
#   'HmwVT3iQYng',
#   'Yh4Z452kiAQ',
#   'YiXbU7k2DmU',
#   'ahi_t9eMejg',
#   'ieX2EkAy5i8',
#   '_2wcR34EdgY',
#   'FUvU8CUDjUI',
#   'lLC6PgSxqkU',
#   'dPZIc-heNZI',
#   '7r3ZKpaBfk8',
#   'AW6zKF7Hrh4',
#   'tO14SM_QTWc',
#   'A6k8AE9MkUk',
#   '5BfhEy9eztg',
#   '8k4zeyG0esE',
#   'ADmnO_o4yrI',
#   '4hW45T5UFyM',
#   'plhGH9GKm0U',
#   'TL-Cj63l6-k',
#   's8m2lqM6DaI',
#   '8I3NhhoNc58',
#   'V2Wl7e52kVo',
#   'n9JKWpfIKCU',
#   'KPQ7X8tBu58',
#   'HV1Itb9-v7E',
#   'gYm1hsuHCW0',
#   '8XZ6BPzwCkQ',
#   'm58hD0h-WSE',
#   'TPvlM_eDX3o',
#   'YbV07tK0sn4',
#   'C-Y9XtNiA9g',
#   'DabGBNzO2Gc',
#   '66QdX9a12Hc',
#   'ZWs1OgNXBGw',
#   'yw7fjyBWs2k',
#   'ZfGweioo2rY',
#   '7jFrczSK-rU',
#   'JpCi8xVRWms',
#   'hB544u4Hr6Q',
#   'VFgt3tB70wE',
#   'QeCv7pe5vO0',
#   'oHNL2-UjsdY',
#   '2qVKgp5XTuk',
#   'lv8D83WO8sg',
#   'atFhU8IEUbU',
#   'wrdinJsVAIo',
#   'PoQqtRco2IY',
#   'Ecwxq9fDiQU',
#   'KCjt_sODyvo',
#   'Wrpw8OWf5L0',
#   'SpZ8Yl0qc6w',
#   'bKV8zxUCk2I',
#   'lSHAMMtpdkw',
#   'bKv7eFhVYs4',
#   'LE1iokxI83k',
#   '0IUmtPw4HbA',
#   'yt0eTtl82Qc',
#   'SUMMxY02Qjc',
#   'lCh0Sti3Ons',
#   'gp6dESldDms',
#   'QoY2YACwaOI',
#   '8XmX6g82Nmw',
#   'CP1yycF65S8',
#   'TWFM0_DgfWo',
#   '45YUAt26sWU',
#   'wT4SQclbxHQ',
#   'w-rjHWSVv1k',
#   '9yZLmULgLQk',
#   'EQIXBZO5uYo',
#   'ZBLUnszFqAU',
#   'IDJZe7oG8EI',
#   'g7YN1ea8k7Q',
#   'OB_AVEqyO3k',
#   'ex2xUPadn84',
#   'vcRtIr_KEXo',
#   'GeRnWYn-GTQ',
#   'nInfHK9MPdE',
#   'RmE_PY-AbDg',
#   'QLFHcAgYavU',
#   'lqb2vWNI8Y0',
#   'amFTT2Uva18',
#   '1B0Xo1_JzNM',
#   'GJrDTl66wfs',
#   'nGcwzUk_zk4',
#   'uJC_2zh21YI',
#   'SuPoYw0MXf4',
#   'FrLsPVyRYqo',
#   'hK6ykAe_l9c',
#   'INU360fq8M0',
#   'Mcm1o8Ykq40',
#   '7e-XCxFQuJY',
#   'AQNctxi8byU',
#   'dL97Yb8t__Q',
#   'lODU9_saB1w',
#   'Ao387q2jCPk',
#   'Bo1vFSTpjLg',
#   'mpeY2YisVbY',
#   'It-Ahr5qwc8',
#   'J2ba9PypZmU',
#   'm9M-Brcp9LM',
#   'CBivmdSh2Z4',
#   'uN0g2KAG838',
#   'KxX1totBEm0',
#   'ru_aR1D42p0',
#   'tBDYDwNaGro',
#   'brV_-P7t21g',
#   'xwpM3vXGAmc',
#   'w69dwiCvSAE',
#   'VpGKByrl5D0',
#   'i_NlBfnXK80',
#   'ObWNI894lnM',
#   'zwVo9shCMPc',
#   'ETv9ObpQOKE',
#   '71pCIOf4OgY',
#   '3l2ZQnHmWQI',
#   '-jVfl4D4_1c',
#   'E0IdLfr78sE',
#   'UgpsuwRgqok',
#   '8QS82wmLglM',
#   'R-UI7ecofJE',
#   'oNCwLdTz5WQ',
#   'CikbTZB2WZg',
#   'lFEU4dycbVg',
#   '3eChfLGmntg',
#   'FySu-TVuZ7U',
#   's-WhhvyeZlg',
#   'cYcUyPq6D4k',
#   'FVUqU30PbgQ',
#   'q0Q61vXAmCY',
#   'PnAKVL4CxDw',
#   'Pf0mjkTDvqo',
#   '37gTJpgP6Gw',
#   'w6haqAeO5lQ',
#   'voSRHo7UHyw',
#   'W-IHy0VD_s4',
#   'e9dmdx7K3E8',
#   'NG7C7SBw_2o',
#   'liAbXcwYFK0',
#   'yeg-FDfsP3o',
#   '-JEbSTsZ4II',
#   'kaceI7A8U8Q',
#   '33dmgSfdKTI',
#   'XqvG_Rc4LmQ',
#   'AoYDuHKsYs4',
#   'my9ZSmQGWao',
#   'y5PfTRyr8S8',
#   'LtikSMaeH8E',
#   'KrbO1nEpmQU',
#   'LBv8BHyOE9I',
#   'gtX9bZe1hNc',
#   'E2fb3Bxm4G8',
#   'w6ylGtvXbAM',
#   'zwIUEGzwb-A',
#   '75jhfCYAjfA',
#   'NF-rjDDLboI',
#   'VKxDbULFDFc',
#   '2BWrau2-baM',
#   'DoZATC3EjW0',
#   '5JO2W8Pcnbc',
#   '77sVQFv5AY8',
#   'j6NiN79aJ40',
#   'WaRLYt3AlwY',
#   'mtYW42_naBw',
#   'kiuqzg0uhMM',
#   'ZKRdfvSUyuU',
#   'eF5VyjO6PZQ',
#   '8N5EInBBYJI',
#   'Uc5C2790C7E',
#   'piH3dDQHAjA',
#   'NZEGRYQVOyQ',
#   'iPPkS1I7LIM',
#   'noRSnTqGF7I',
#   'tSiQb7NGw2o',
#   'h8jmJvry36c',
#   'iRJ5uEO_hYI',
#   '7NoeFA6XNHQ',
#   'yDsm26M5Fr0',
#   'umQYEsj4ick',
#   'oy3fknO0ujk',
#   'rKfzcIHRJbg',
#   'lNPi4FbzZpY',
#   'YhFOE1VzLmo',
#   'iw3Z5bo4Q2I',
#   'KorfWbBX_L8',
#   'eisIMs6BFhI',
#   'kYlTPQLA9PM',
#   'bBk7mHryHLg',
#   'OM7NqJJkziY',
#   'zlQwXx_DybY',
#   'xyIP7leYttI',
#   'kRi3mAwb310',
#   'BKepGjik05E',
#   'KriI8ri11WI',
#   'd7E8iyE_JCs',
#   'oKzy76Odap0',
#   'S3ob_HTPAhg',
#   'vpAxDSEfReU',
#   'XOYjdCTrias',
#   '8I0NnPpdYO4',
#   'qDbMAtQAkUk',
#   'BqvTmVLzGio',
#   '8lOFBbiYb4g',
#   'a02a9IpuB7Q',
#   '6O6i6FUirWU',
#   'Gwqu3e8eheA',
#   'tBGlvjbmRec',
#   'BXZkopvjKvM',
#   'HbDhCNbeTI0',
#   '_nvx95BMVQM',
#   'z5xQEMRyxFs',
#   'DUSEU4IDDaw',
#   'v1p8FvwXpk8',
#   'TeVaiVp6FKM',
#   'vbKYwAPA094',
#   'w3C3x9ZFWQ0',
#   'vFTd5QLv-vg',
#   'xuMeNAJ36_4',
#   'slGG45ZZpbk',
#   'kOqZ0KPkMZM',
#   'VML_bmqgptI',
#   'UmYSkxjmmtc',
#   'Y7smWnZvVb0',
#   'ZLonjX8tnQ4',
#   'nlrlbV5B7gI',
#   'kU22Erasf2Y',
#   'OUvs_EpsKd8',
#   'OixIFVi-zf0',
#   'AC-PfK0zsxM',
#   'JkVYD8lJ3bc',
#   'l-dpw8SmaFA',
#   '6Z1t5_PMDYw',
#   '3L4BO5sACQI',
#   'HGqvfC_BBwg',
#   'WVym3eq0Q4g',
#   'NW5M9gSLexU',
#   'ndISt3o5IwM',
#   '7YM2sXNQL6M',
#   'AAKtmZVbHW4',
#   '6juYuZWbqc8',
#   'ydLvr5Xk4CQ',
#   'NXPsj4JuVC0',
#   'fDfdBSgpHpk',
#   'UnwO2ydVJLQ',
#   'uN3liE6crr8',
#   'ouGpEtl4DMA',
#   'pGG7x4uHUqg',
#   'v4L6Bvb0F1c',
#   'YDkKOn0tLfQ',
#   'kg6IzCkpw6E',
#   '3jav1_FCcnQ',
#   't1kx5vAAWwc',
#   'dPh4I7PIB9E',
#   'fYVXAe5S0lA',
#   'R4jjoVxdFJ8',
#   'CZ-QuW44cvI',
#   'gbj6OQHk9Fk',
#   'DfeNzwMmeMs',
#   'pMbOdY7JnpA',
#   'hq20U4fUss8',
#   'PGeb_Y4TR6I',
#   'AfCSib1wk7U',
#   'ZC_7vby_cEw',
#   'QNXOWsSljSc',
#   'JowTxIv-eg8',
#   'UI5j__JXr6A',
#   'FiyHREEPbHw',
#   'hop0o-R6Djc',
#   'mhE78QOEGdo',
#   't6BNF5mauro',
#   'xJEm42FsTqc',
#   'uUKcyk9LjRU',
#   'MK0tUTZEhkQ',
#   'MDobBdBGoIY',
#   '3aDBiweVLsg',
#   '3aUtYVr62lw',
#   '3AEFkktm8g8',
#   'qMhmgTHzH7I',
#   '8UjWPZezFD4',
#   'j9m-R11AfoY',
#   'FqenTltIhuY',
#   'zLG7KEgH3nA',
#   'V7iR-ErLToc',
#   'Bc07ujfGxKc',
#   'On9JsPg3YyU',
#   'MQcHKcilFnQ',
#   'hlg6_T0czzs',
#   'CLN2ioY0Nik',
#   'SD8V0_GoJHc',
#   'wOdRlZ4mi8U',
#   'K_lmuD7bC4o',
#   'BB6nbFaPXuU',
#   'W3d1cmsG8BM',
#   'f_9A0giUqok',
#   'qv8TCmy7v4Q',
#   'IeNDLMQAIEU',
#   '10kjSc8RUg8',
#   'goG6OKWb5n0',
#   'NsfPetUEzcA',
#   'xY3hIvYXnm8',
#   'FQ74oF1Afr8',
#   'F_TD3icUsrw',
#   'XZelh0zeaOI',
#   'Vr-PrrfzNcU',
#   'q7g5uXCN8Og',
#   '5yzkXzPBf7Y',
#   'neGWHZydtQ4',
#   'jLO7Yqz9-K0',
#   'WPjXGuMKDpM',
#   'iTD4UJqZTdM',
#   '6c4mg8fCHYg',
#   'xMAssavBlSQ',
#   '2v-FVgwcY0U',
#   'a-tcmd8D5yo',
#   'tsus7ovzs3c',
#   'ss8Vy1aJgHU',
#   '2vwVHh_blVE',
#   'pm_1Ml8PXP0',
#   'ooIwS3oi1dQ',
#   '5UOwcQzb0_o',
#   'S35BeDGv6bQ',
#   'oSmNXS4gSc0',
#   '6XIOV6eLa0w',
#   '58XDhjwxU_s',
#   'iEr-YwZnEAo',
#   'JP5QCetXxCY',
#   'vYi2jirTZ7o',
#   'ut-YnTF-v-w',
#   'qlTAEQ4l0Ss',
#   'kyl9A2WpuH8',
#   'q7k8HzYZ-V0',
#   'L8SWCqbhx4o',
#   'HXMlwuN6qRw',
#   'FJJEUcFnpC0',
#   'Hb-9zk5Mcr4',
#   'xaZAd8u-YrY',
#   'HNLm_XnoFyY',
#   'wBuYL71M9C8',
#   'HJopNEIQrV0',
#   'fWkHD_LiMlo',
#   'PMIod8u1nx0',
#   'hkUPi0anl4A',
#   'CLwR1hLvCY0',
#   'vrJ1g9UOcXs',
#   'b2fuXYlsrGs',
#   'MPCCaDiMRsw',
#   'Nh0CYHvVDs4',
#   '-oCna_H5HHM',
#   'eqQtrmdzat0',
#   '4kCl2ucFE6s',
#   'iXFYvZljWXg',
#   'df40cZutEAc',
#   '0KApUMijGfs',
#   'tMHTcncZzaw',
#   'h7LgS9f8Yls',
#   'alXxg904PcU',
#   'XT0ZYSlA7JM',
#   '3h9QuhGB__8',
#   '04G53OhGya0',
#   'Qa0CBu9Ezr0',
#   '8sPmGsFgq_8',
#   '_pyNqgPvZb0',
#   'M8lbUQwntqA',
#   '4531ANn0nu4',
#   'KBJiHACcA50',
#   'opqRMe4iDHk',
#   'XDjvidy-PuE',
#   '0g-Fsdgp8eA',
#   'QPVpep10ptA',
#   '2jPQ1h2K64Y',
#   'awIPdwjxzaY',
#   'UgseHyhFRV0',
#   'ppcP5Qk4QuI',
#   'LLXrfMirdwg',
#   'gpPp590XTmM',
#   'cT4iEAHosZU',
#   'wGDj7SroquY',
#   'faOGxKPQFbk',
#   'ykj6epk7Jpg',
#   'JW-jmlLc3A8',
#   'LuWsedNgBLM',
#   'RP3vdkeCxfk',
#   ...],
#  'Mrwhosetheboss': ['-OmL0SWZ30A',
#   'WL4RWNptU_Y',
#   '6Mbpa0zKaQw',
#   'KGZ4VFDvRGY',
#   'HvnY2IWoAGI',
#   'quUFmlvjSHk',
#   '78cX0yLJPMw',
#   'mkcgVN90zl0',
#   'DnY6J7YAsGg',
#   'prZK4ot7lRs',
#   'HvbOESd9u1w',
#   'KXl8uY8SUPo',
#   '5VMckmQneCk',
#   'fL56fM5HSRM',
#   'undwfOwhVsw',
#   'xVEtLb8Wx5M',
#   'ShJw2I8cgBE',
#   'oVPWhVgEF0U',
#   'UdpFPApfQ_0',
#   '0PXAOIrgyk8',
#   'NeNfrTx9UD8',
#   'V8e_Ocuc5gw',
#   'FXlms046z2s',
#   'epWcUV1F9CM',
#   'lU_8Hxh3RZ4',
#   'L190UWL934c',
#   'LWEDJ_YgEaA',
#   '-hlwlML6pEg',
#   'yeK6hWmNkXA',
#   'rj-db6BAEg8',
#   'Yr-VGSvi8AI',
#   'b40BxyZGW2I',
#   '16w6qzwN_3Q',
#   'P6B_uE-mYDQ',
#   '6jVUSsByq9Y',
#   'swx8m5o5Hb8',
#   'jKcHOJDwm9A',
#   '4qWR-YCgysQ',
#   '8CikBtgorWE',
#   'mk1h-ku4GhY',
#   'GbyOPPXbxQI',
#   'neIYdLysqlk',
#   'BqvtFfkbQxs',
#   'o7m-vmVejUM',
#   'ZrWfNrfflhA',
#   'YX8ks42Azn8',
#   '8Vk_2Kq9Njw',
#   'mGv4wOpo8R0',
#   'uSGVk2KVokQ',
#   'LbQIjt8wjJM',
#   '4RcThoRG46c',
#   'XTXBjoR7xJU',
#   '4maJty0vQjI',
#   'Yl_19rCQQB8',
#   'vSIbvJB4WdI',
#   'cRPBp2tRxFY',
#   'frUGYJvJnZk',
#   'N11x5t0jE1w',
#   'IDwudJjH5u0',
#   '8p-hK56jc14',
#   'gkYfm8G7lSc',
#   'CpCZNCm5zgw',
#   'wrGPUddQ-0w',
#   'DCu6xpJeqkE',
#   'EHNuwI74zew',
#   '8Lb9023_D0A',
#   'xTT_vpF-ogk',
#   'L2f9NelGx8M',
#   '4Gh17DmQ6n8',
#   '3Ouu9OqfTk0',
#   '8L5Iz9t6g_A',
#   'W3-SjFWLPdk',
#   'CZ4Zm-_ERZI',
#   '5t1okmz8Pyw',
#   'JbUIWFu3coM',
#   'iAMIqJ7EJ1g',
#   '7InMuwT8gdg',
#   '8wM5N8u95c4',
#   'F0lHIMxoZEw',
#   'obzwqMm7wk8',
#   '_Ki4bS4V2gQ',
#   'AClfhmJYyNc',
#   '25vQ1YcBZZs',
#   'kqcphMpZ4sU',
#   'YPGQEEsuvkA',
#   'beYu7lZbBXk',
#   'j4M47qLTeJ4',
#   'bqTK7cyER3A',
#   'xF-R2EV3JiE',
#   'xNv2EOc6ma0',
#   'Ay9RL5YQViA',
#   'PtgElT4pK_o',
#   'y7k5TsmAtRY',
#   'Fd57NOavMWs',
#   'YlBl2x_wnmM',
#   'Rn4si0Xorhc',
#   'zOLVvzig8-s',
#   'WER_dxRn5Bk',
#   'S9cmoZFJTD4',
#   '_ccxfkmD9Ws',
#   'oreZytDYoEU',
#   '82jYblR16QM',
#   'jocoOcvKN3k',
#   'NslVcXENSV4',
#   '11OQcqP4JDc',
#   'RRibM1yBZK4',
#   'tC5DLrR84oE',
#   'wVYG1mu8Lg8',
#   '0O2yTG3n1Vc',
#   'n2T6L9ToVwk',
#   'OQSaDL7DHhs',
#   '4QJq2h8tCv8',
#   'BiZcyJPoDy0',
#   '2s2SZb83jyo',
#   'I6SvsYgmMSU',
#   'Pf9KXfo5R18',
#   'eSucdOAIwrg',
#   'HgqpFKiMz-I',
#   '5MhRZp2uunc',
#   'Vdll3kjkAJQ',
#   'eemYfA2ngyI',
#   'LdlLUogNYMw',
#   'hGYS-NCNon0',
#   'GHYg8cmUiKM',
#   'dQmYR90xSxw',
#   'WqJhvUYLRzk',
#   '5LAmDKf0mlY',
#   'CA1nuuqSisA',
#   'HvoBci_GC8A',
#   'ioHSADHA-Go',
#   'IOB3ilwdWpg',
#   'J9-9fP_pcEc',
#   'btmeie5A4yE',
#   'J4aRcs66Nlo',
#   'uy9Vezm-ah4',
#   'zu4fYpQHsIE',
#   'zyPZuqkLaTc',
#   '1iuaVRIhe5c',
#   'LZYfSYXY-go',
#   'hTqw_CGCmNs',
#   '2eDLFXPrMtk',
#   'xfgTQ5sOzrs',
#   'HRqPtBXJTSs',
#   'po2K2XNTYyg',
#   'ZIudTsrhfCw',
#   'ynVZ18811t4',
#   'mISvJhV8w-w',
#   'VlI9WLzvGks',
#   'MqVi2KuJwlg',
#   '_c1RvIU6WAE',
#   'eqJSXneL2bo',
#   'b0HfmY64eSE',
#   'lHtocbq47o4',
#   'es-5WR3RKe4',
#   'gkJjEQmPPPM',
#   'KfhdguONGOg',
#   '9tcyWI45w7s',
#   'qI3KFg6xHFo',
#   'IhYDtLzmRQI',
#   'KgSL-0S-TLw',
#   'l9m3IKG8i88',
#   'fUkpZPj-Fxw',
#   'nk0GiiwRS24',
#   '3ZDcr1icSo4',
#   'NzE7qj20Xwo',
#   'jmriIVcEOeE',
#   '8VvzURD-3xw',
#   'lVg_F9nS6JE',
#   'JHJN1t3uIng',
#   'u06hIk7FqW8',
#   's1XVb4mdELc',
#   'OVV8UEHOkPg',
#   'Vq-XWcq5esE',
#   'CPlisjZ8CNw',
#   'JwAfHEHQKto',
#   'L6hBas4FfIk',
#   'YaPe8DgI0y4',
#   'CaahEekBH_Y',
#   '1aRIQWinZHc',
#   'nPghKX_IJAU',
#   '98Auml2vFuw',
#   'v7mkFuuag5c',
#   'C7dbYud8-9s',
#   'KLWdtl5S51g',
#   'uY-TTXxjDpU',
#   'THV156MB0Vw',
#   '48vET0WDkqc',
#   'ucfJtpaeuIA',
#   'BY8CjMUoVKo',
#   'ak_F8x4giIo',
#   'ZAjSOz3YWLM',
#   'cxQ3vw8WRjE',
#   'ITdxTuPn1IY',
#   'r7COWvxlN5g',
#   'bdPTfHFPayI',
#   'fTVWYhvDgb0',
#   'Muv0wjyjSNs',
#   'YxLSq7TYV1A',
#   'rOyacTrWMrI',
#   '4pSWXiAWcUc',
#   '-hE-c84DpcU',
#   'S7r_ipKQjkA',
#   'LUlMLhKqweg',
#   'gPSubG8qHNU',
#   '32slGhAH3Xc',
#   'GB_DNkfjXbI',
#   '2ImBiZobav4',
#   '2MiA6l-Kaa4',
#   'SrYkrsBzbOQ',
#   'X3UMA7DstGs',
#   'K8zCgL5h4Z8',
#   'FIEbMsOm-Uo',
#   'Ri-HcFlNcJk',
#   'nk0qACYkbQM',
#   'QdE-_Tj47f8',
#   'n3PJjAAv194',
#   'kMiy8ZywF88',
#   'e33w1c0CN4U',
#   'yKe1H5cIVDk',
#   'eLDvm9czyBQ',
#   'VjBoxeKFWGQ',
#   'eXb7VgQ9yLY',
#   'vZoKJA84qHc',
#   'jAwhBH32F1M',
#   'rWssyQD1uMw',
#   'nF_YtQkcyAM',
#   'TIsNHnTJk6Q',
#   'FmeXx1OScwo',
#   'Z7iBFklVU_I',
#   'SSC0RkJuBVw',
#   'ajsv2d-H3LU',
#   'ntz2c2z54dg',
#   'h359LRmMZMU',
#   'kPnpE_wAy9Y',
#   'QOfGZC6xEb8',
#   'nSDrrKtqISo',
#   'vkBQW8NZk9k',
#   '2eK9TtRwKFY',
#   'bk_o8N-Dzus',
#   'g_DHKoj7n8U',
#   'wt2WGqJkISk',
#   'uXy-4up26uU',
#   'DWw158c4Mc4',
#   'U68Zlppcr30',
#   'Q8d4FGWZDbE',
#   '94LDWSXT7HY',
#   'nvVWqSJdW24',
#   '8TlrXc3TYgs',
#   'zhZVp1DtjzY',
#   'l9sA24djg6Y',
#   'qUzpCqXZIYw',
#   'vGtJRrZUjd8',
#   'eVXfsNS-V_I',
#   'wBHQygi6d8c',
#   'F2Q5vXt4xic',
#   'wGQHHpemIjk',
#   'k4aDSgRXyEk',
#   'SJNbnVjecf0',
#   '60LZ5Ie8XS8',
#   'oORJNIDy3B0',
#   'Iot6JCD8Gcs',
#   'l3ujdTrbD6w',
#   'OmmbQRSuNys',
#   'Ceqabjjgh8o',
#   'd_3U5MKqRKw',
#   'EKYJ-gwGLXQ',
#   'IZl5ipoTIEA',
#   'ZmyTmCL6Hlo',
#   'PJyD4IAzNRs',
#   'CKvZ9KhLgHE',
#   'heXw4nN7OAA',
#   '6bQqgmXGKqo',
#   '1_2hSsibj-E',
#   'V4D49YYihQI',
#   '5qia0iT5LNg',
#   'jmWmiQt24sU',
#   'GX1ZSQdwfQ0',
#   'o-A6OXsxAVM',
#   'XuCYpIMdF9g',
#   '6-fCM_svdJ8',
#   'BNlMQHknwSs',
#   'qmQ6QwG1b0Q',
#   'AQRNNUqinQk',
#   'qdjASN3mHIE',
#   '9Shb6up5tVU',
#   'g8rfBYVbLqM',
#   'zz70o2Ia4X0',
#   'lPJGy8g4cGk',
#   'HMX0vrJj5nM',
#   'yIdoGu3lCIA',
#   'bfv5w_sbfR8',
#   'o2-2mqO07lk',
#   '_Wmj5FHbJHg',
#   'lEMG9AzaRvg',
#   'syCmXKNxvwg',
#   'Kai8LDp5S2g',
#   'EaEjIoQnFXo',
#   'uOrENBYWQOU',
#   'EygCjCrqtyA',
#   '03VxdOzPFSQ',
#   'NLFB4u_fJK0',
#   'aKAZkC4pWSU',
#   '377LhTg1xOw',
#   'cnNMo4u0L4M',
#   'S1FkabHFtoY',
#   'wqeM11oxX3s',
#   'BTe5reYmNig',
#   'WKOkCpMZ3Z0',
#   'z5EWf0gGoms',
#   'IVdZhcvIp90',
#   'fjRaA-8CV4A',
#   'xpsWUrwQB-s',
#   'piLRQGukXqc',
#   'O2CdRDshmw0',
#   'XSIGG-LfoKc',
#   'JXJqxBEDxdM',
#   '7zqNL-nzYfI',
#   'xHu5IBr7zqg',
#   'd5_n47NWwY8',
#   'aBIsrZ3yEPA',
#   'QJplvV_Vyn8',
#   '1Nef8LPO-jo',
#   'SRz6Kc_aqEg',
#   '0BR-HgA3mlo',
#   '8kUAG8EaOiQ',
#   'i1aKpceiIcY',
#   '5fKkXFresYI',
#   'gPZnKfTzv5s',
#   'vtvFVH9JdNI',
#   'THw-wXt7wyM',
#   'keoRX-Lni5s',
#   '6Wl6mbTnXfk',
#   'OfM0GqsIB6c',
#   'rgTGKcoq2Os',
#   'AsP-l13GYDs',
#   'GiK0vmHDBAc',
#   'yP3WyefjzaM',
#   'wfH2qpVvpaw',
#   'CpfNJoIdWpQ',
#   'qDMY_n5b348',
#   '5l0bqxUUY5U',
#   'a0zrnEnUiYo',
#   'mvvD21aUYeA',
#   'wCXYST7y3-E',
#   'uPxkrGL0l7U',
#   'EUpm-acqvZY',
#   '0rCbfsuKdYw',
#   'Z62hqbFL45c',
#   'AaKe19KV5Ic',
#   '2TqOmtTAMRY',
#   'L1uoESXxxQ4',
#   'dXmxE-5n9E0',
#   'lUzpK0tGFcE',
#   'KAIJB6usEZ0',
#   'Ty6ajzVMvVY',
#   'ohltpJStiKc',
#   'Wuq7lS9rljw',
#   'AaxPLnvCy08',
#   'xf2DPY3vGto',
#   '0lcUBr_gmnc',
#   '0i4z5tqRzPg',
#   '7DFNyivh9uE',
#   'IrXLRxSsMbs',
#   'DxVRCrNJWZc',
#   'otcZMrWQKSE',
#   'pDZdnbI0MAc',
#   'RJwDpYmiQ8s',
#   'lmIO18kLcZU',
#   'XzKbTtFhJ8M',
#   'iDdN5cOFB1g',
#   '1_2q9JclfcQ',
#   'QdkRuu4jvsk',
#   'nmY2kgWYwyQ',
#   'bCevmmgJzQc',
#   'c74snwU5Pmc',
#   'LAMYke-v8PA',
#   'mxiEI65M9_M',
#   '8CCtqtva6ok',
#   'w7ZcS2vEzIw',
#   'Yok_WszgNmA',
#   'y4M-hmNsSNw',
#   'nVwOd_6yyf8',
#   'VoH1DKidj8g',
#   '0pWTRsztTtY',
#   'g5skXHWcDrk',
#   'GPJ210kTrDw',
#   'MKbIHOvtVJg',
#   'IErvIekMD3U',
#   'F2EfTe7YOT4',
#   'LTQ1bqpoFSc',
#   'VuG4BcghOSg',
#   '-Ba5-h4XN94',
#   'X3NYdlc8XgA',
#   'kwkjQRT42Qk',
#   'GCmiKaLnd7M',
#   '6mrh4o2RPpI',
#   'RgJwPco3wew',
#   'LFmcYQZKoEE',
#   'mZJ6sn1URAE',
#   'hsgMPBR7iXk',
#   'LA1tah85dvA',
#   'FZvee3-PEzo',
#   'suT82AdWfTU',
#   'n0r2rENgvwY',
#   'n1xb_o_nhhc',
#   'IQQCoJiZj8w',
#   'ZoP80SfGscM',
#   '84FatKnHhJI',
#   'WeFmNJikaxg',
#   'R3zfXc8nVQk',
#   '9V0lXIK9DZQ',
#   'L1Kb_ZujBPo',
#   'sC3Q1pGHvBI',
#   'zT1cTTzRi_8',
#   'DDAaayleHUE',
#   'qTtgzNGRAfA',
#   'KcMQO7ckh3s',
#   '3KPY-gjmHWA',
#   'bBcwFWS34ZY',
#   'CwROcBKXsus',
#   'lg6Jlh-bEhk',
#   'QBTwzYKx-kE',
#   'wkReOA2nBn0',
#   '_zRUCI857IQ',
#   'rYQgy8QDEBI',
#   'syB1ezRvKpU',
#   '6p3U-uWUNps',
#   'XfpMPZTyNQI',
#   'OHlZXyhG3eQ',
#   'Ch4RW28A9A8',
#   'zDG-n8JN_78',
#   'AB9KT9KxUBo',
#   'nb0BG0ixuQA',
#   'Ijssm6Qv5nE',
#   'sUJfW4xJlNk',
#   '-uAZFVWz0no',
#   'wz4MLJBdSpw',
#   'wadg_mLOPJQ',
#   'cNVDrf3v-ds',
#   'Z1rCDwz-yg4',
#   'OxMVmeInnK4',
#   'xRrSo7mW3EE',
#   'FW3wNsTLCEw',
#   'QMWlRWnAZH8',
#   'xd2bKrDzMTg',
#   'WVPM6D-3aZo',
#   'eiDoBooB8-E',
#   'rsLJLk3nx8k',
#   'J1sIZguHwp0',
#   'PvWMeo1tcgQ',
#   'OmzKPmSW1Bw',
#   'qxRpzr-862Q',
#   'Wuk8AhWcQNY',
#   'lBb3xGgIq8E',
#   'yzBs0Ik5wLU',
#   'Knv5_zc8ghA',
#   '5P5hYvlKz7w',
#   'FsHrV26dKD8',
#   'zSpdoAZryWQ',
#   'uEWi0PskzS4',
#   'GSudn0qB6u0',
#   'djpIExCHWJc',
#   'fgqtr3I_68I',
#   '7-vbCnf5mxQ',
#   'xgoPfNCWI6Q',
#   'B_sFhtmdzYw',
#   'cJKQdzopuco',
#   '8FcER6P4CQo',
#   'vT6HFpOPE-k',
#   'N8QYY7rvLwo',
#   'j1wFsMBArR0',
#   '8Xi8HfOCG8o',
#   'EI5CbFACyTg',
#   'L3SflBuI8Rk',
#   'b5h4a_O5E44',
#   '1HvrmDxSFnk',
#   'nZMUzaLV4X0',
#   'eDW44A_noK8',
#   'LiU2VAza8PE',
#   'mqppAEK0t_8',
#   'AvcAovqG5Kk',
#   'ZI58Itw9B7A',
#   'JM8iUU3NkS8',
#   '7jiQ46OMcCA',
#   '7uzqTBrEbDo',
#   'aAkridWMmyU',
#   '0MNiUQz7ed4',
#   'EL-UCUAt8DQ',
#   't_8M_2clsVw',
#   'FTU0Yi-_dGM',
#   'zzQY7hjiKtU',
#   'pLY6Dv75OVI',
#   'oEJ-Ru1Uzjs',
#   'wsubahcOoIs',
#   'uje782G0xk0',
#   'WVVRVtJ9ujk',
#   'nqNOyYBwgak',
#   'l29HHHP-9V0',
#   '7gC-1C8l8H8',
#   'aYPaso1zHow',
#   'wGk8du2VVCs',
#   'oiB8JmBh2vw',
#   '165bpjQ2ZNs',
#   'mZR7LOhu1FI',
#   '97-J0FsuEM8',
#   'ou9CjRWq1tM',
#   'iXKvwPjCGnY',
#   'hRIT58zTiBE',
#   'ndBE4dBmGR8',
#   '9sdwaf76D_Y',
#   'ZE3TpdRJygs',
#   'D1GF7bTxv20',
#   'F5j3eB4xBRo',
#   'FxX07xtvXEI',
#   'aeQnQ-vjtuY',
#   'KRrsIp1kNtc',
#   'rEIx8C2UhX4',
#   'SJGkeVZXxSk',
#   'FXqoPVC72xs',
#   'V40l25LUoEc',
#   'MHWnTJwxsKM',
#   'QlGqZCFfZOs',
#   'Z4LS34F1qJ8',
#   'jOt11ubyG_E',
#   'tNy-0cphhNU',
#   'PaEDEOnBCJM',
#   'beoLDApHfAc',
#   'Strjq-WZF7Y',
#   '6CUSe8kgIE8',
#   '41BSrVeb-h0',
#   '_tq4Pb0OBYE',
#   'IDvsQ2duKRA',
#   'cDrxP726L3o',
#   'F1ARTncez-s',
#   'hsOv_VU3wKA',
#   '9guiRJPsg2Q',
#   'eQ3OV_an7Qo',
#   'qvK_4Bkc-gA',
#   'EFnClTCRFkM',
#   'f5Q83Y-guO4',
#   'RP5d1n-XLbc',
#   'b3uQHiW_8sw',
#   'w_OcYyQmPBk',
#   'tyxYHIcIJoc',
#   's-x-Bo8HVaA',
#   'GDd5w3kmhHM',
#   '_N2YLDWS2Xc',
#   'yVWugcxIxXY',
#   'CadhtAJtMoA',
#   'ztaJH-PHCjc',
#   '466gJDf7jmY',
#   'MKwpbC1bB_o',
#   'QGwiXajigZ8',
#   '5_wi3TR-MbA',
#   'VK1He8VmaUs',
#   'ZRV0Q1Wftt0',
#   'KQaZa-8ku30',
#   '5qa95ag575k',
#   'CfgZGjO99ew',
#   'hI0lNptix4w',
#   'tuaqgB1AcHw',
#   '0pss7E6IF_8',
#   'OSRY-bJknqs',
#   'RPoCsWIyZWg',
#   'N9xiiVPa7ZU',
#   'SZpVGgZDVdY',
#   'dJCA_RxBXuA',
#   'Zl6BSmSHjEU',
#   'yHvkpmL-NTY',
#   '14x5n_oNEV4',
#   '085_hlIcLu8',
#   'leBccIkULds',
#   'zFv8NV29P2Y',
#   '788E-ATJ3pk',
#   '_OeUe9DTvN0',
#   'k4bs5rdZy6k',
#   'tp-gaXL0HJw',
#   'VFYAACe2Nmk',
#   'ZSZoudGOnDk',
#   'x142pNM5bgM',
#   '9gKYWjA5OkA',
#   '-EB5Q5yFD7U',
#   'dSKALhlsuE8',
#   'HJtHw2U_esA',
#   'jVYZfulljqo',
#   'omx7n0sIHfc',
#   'W5hBBZLjQzs',
#   '37eNw3CMywc',
#   'E19xIwAiMfo',
#   '1lDOLdqwjGU',
#   'Htj4z_nAOH0',
#   'GAp8NVlA5Lc',
#   'rIbysRUsOzI',
#   'xmalvGgWIoc',
#   'eT22wh0qEok',
#   'Qdifbq7i-NI',
#   'WqfJXQikp6w',
#   'cVOFMZ53ssM',
#   'TXk30OqvkEE',
#   'C9IPyPBDZQU',
#   'E3IcOO-9pZE',
#   'MBlRX0Cnyzs',
#   'G4v3_3cPh0A',
#   'tKuHEBX9aMQ',
#   'ctGhcJ9jIqo',
#   'fadHUHIlGXg',
#   'u0cGxJI83LA',
#   'R_7gFbfB_QI',
#   'ZkUo-0SMdX8',
#   'dhUrevQKFbo',
#   'KQsBfSDE0Eg',
#   'QDkcaQeuzV8',
#   'dhc6sbkyJAQ',
#   'L_Shqjv7t2c',
#   'HcwLdSwb1oQ',
#   '2RpJwSz_IqE',
#   'sgF0KXNYpQU',
#   'SNl8lP3roEo',
#   'cXh8WhB5eLg',
#   '_OVavbZKXlM',
#   'CQ2gHfVPK5Q',
#   '9a_TvN5Aw6Q',
#   'kjMj5CeX9gc',
#   'M7lBJ2XoDZM',
#   'M9PfNjmXE4I',
#   '7OMhCE8d8nI',
#   'q131szcyJNM',
#   'KgOYSy-q3m0',
#   'YoSYD_bO3q8',
#   'auj71eUGTg8',
#   'Pa4m6gpUSMU',
#   '_ERUGUSkZkQ',
#   'zkrETvkPRF8',
#   'mFJjsbKNxN0',
#   'uM9k6SC23Ow',
#   'QBi8mfMw33o',
#   'EMhNh5Kf5sM',
#   '7VYl0FBjRzo',
#   'Ha9wiyqpsMk',
#   'rvK2eedlaXY',
#   'P5gTkt42jg0',
#   'ehtBBi37tDI',
#   'kCCXMlcV-0E',
#   'FA1JAsLt_ss',
#   'Ryy4b2R3irI',
#   'JKLcUGgA5zw',
#   'hZ1FaoKPo0I',
#   'uWMlP7kZgmw',
#   '0q0nN978MKw',
#   'SaceWOjSbbs',
#   'Y7dwBw09MLQ',
#   'iaK3Cg5wg4I',
#   'jUP9ma10Z24',
#   'd0bvhGwNnwQ',
#   'E6Q4X-pqaDA',
#   'dtK4hmpQxZo',
#   '2Z-WEdWCoW0',
#   '0bDLrhkbOOg',
#   '8n0-4NsV6u4',
#   'IR6V_6xqWDU',
#   'xJ_C6-Vvx7A',
#   '5iIg7wmEz20',
#   'Z5TG2f49DoQ',
#   'Gs_gKE0yvgU',
#   'JmwsO4XR848',
#   'Yz8VcDWgpIM',
#   'IrrRFX745-Y',
#   'LgXU-6XJehk',
#   '8E5I1d-aGtc',
#   'QgqinnFGqmQ',
#   'isD2o3YSI34',
#   '5Y4lOAKhtvg',
#   'EQvLtEaEX0s',
#   'Wq8hN98fA0g',
#   'Wk9h3YvmHhw',
#   'e7HX67ldEzU',
#   'WX4AswCzwug',
#   '2PnaJ9fzlfY',
#   '7dUmekh6m3A',
#   'MyBJ7Woh5_w',
#   'e7cxfM1oDKM',
#   'S93h5J65JKk',
#   'wWUUTGBgzwI',
#   'Apwdr6K8ZVE',
#   'yIy2nnjCbWo',
#   'IGF9eYAp2Q0',
#   'HHBLae6RX-4',
#   'yuE_gfC6Pqk',
#   'RI59KEYW19Q',
#   'hqls57qYEYI',
#   'HPmXvLpfFRE',
#   'rMKlkTIxwrs',
#   '1gZ_9e3vSZI',
#   'JdOL59gMPJs',
#   'KgAkbwfpmkE',
#   'Z3L0Pqv_BbU',
#   'jpjz_V1X-z0',
#   'Q3zyFC0pc9I',
#   'a2xwja_Vhqo',
#   'K8e7uR1-Vdc',
#   'g4fhEav2Rj8',
#   'uFtwDtQTbjw',
#   'RPYml8UMAgU',
#   'rpqM2tUuRwA',
#   'uE1xN8d3WAY',
#   'MmTezelE3dM',
#   '-CioG7iu6JI',
#   '5rtIdVF_GKk',
#   '_wRPspdnTAY',
#   'wmyKbRanHJQ',
#   'tvLSIyhgG_A',
#   'PotqdUICSGU',
#   'd0ojqj70VDY',
#   'jKfQoPsy58A',
#   'fotDjQOkUrY',
#   'SVW-L8xbXTk',
#   'gSLVen1H8MU',
#   'QNva3bnuq-Q',
#   'LkiniAkBOyU',
#   '8jQbqRw6Ofc',
#   'pbTaOWCGmLA',
#   'sez7hmRcJ-E',
#   'pG6cmxQQTKE',
#   '0csa3S_omL0',
#   'QUmoTujgXlM',
#   'HztMkTvLDsw',
#   'PPUdt8fFXrk',
#   '48QQZA5yqZQ',
#   'TmQJ0SEccOI',
#   'JGw85BXQrvg',
#   'N3xcBB_wKnc',
#   'BihihQmLyuk',
#   'tEMLvHNsOak',
#   'OCs0qhWfJvQ',
#   'kL5KW-9DG8U',
#   'jP58_8ryoF4',
#   'lQ5rv62Hk2c',
#   'hHGAg5NxGIc',
#   'c06HoSJdDjo',
#   'QkzkEmY2gL8',
#   'xcsMbPoP5jk',
#   'yobbP789IVs',
#   'S_N2hB1gQgA',
#   'KExn_L3d6Os',
#   'xoeUsP5hlqY',
#   'aBgKfJjVFBE',
#   'ozMjq8ljy4A',
#   'MnSwbf4EOlA',
#   'VFgHoxmrhfk',
#   'BaEIGEFcTTQ',
#   'jPZUdGVY_m8',
#   'WohCuSb3dsM',
#   'CdmdFJrOxVw',
#   '53Mq4tFDg_w',
#   'cLI_eK2rdto',
#   'ckANfOMhirg',
#   'hrhOQ0gvs20',
#   '7giHoXCib50',
#   'NcJLKi62wgU',
#   'OBfk79ecvk4',
#   'BNyjeNgl7sM',
#   '4TATOW2Bfpc',
#   'Vx8jCq9_QNI',
#   'GXlBbvCOXRk',
#   '57Z8u1_zMIo',
#   '633Ncn9E4ds',
#   '1mkG1zK9m5k',
#   'OtV1ZTB6-7U',
#   '3oOmU3-_sfQ',
#   's8UOhLRdQ5g',
#   'dimNqewGw2g',
#   'Jo3iUrS--kE',
#   '96YWqJvJxVI',
#   'VylOQ434R2Y',
#   'UiBym3b8Hok',
#   'o9Bn6-BEZJY',
#   'rS7DDOtAJZY',
#   'mTcvWCSIfSY',
#   'wt-Vg8R7w10',
#   'phm8ZQPqpFA',
#   'd7Ux_NjLDlM',
#   '46hGoUhnwz0',
#   'yDNWqrvn7Cg',
#   '8tBN6ozFDPU',
#   '3Gq15WTP6Hc',
#   'TPc5en7qxj8',
#   'HYz7qQbqazE',
#   '1oEHWSaW08s',
#   '1u79tALgR4E',
#   'oVUA0Twc884',
#   'OgL6jKTf2LQ',
#   'mXc0rp2xQOQ',
#   'wQeT4FtIIwU',
#   '7soafZkcaUU',
#   'H75uceF6fNc',
#   'P9YBUKa1h0E',
#   'ozevyZa-CPc',
#   'gHc7m8MBt5w',
#   'UYlBE9wLdCo',
#   'lWqzRF5AhWQ',
#   '41yeryL3qI4',
#   '3f26-27zap4',
#   'ze9NatbbYyI',
#   'SSoOUIQxZ38',
#   'A6gGZxfV_Kk',
#   'Yf6kJUtMIgU',
#   '20R1-S2kYfs',
#   'Zz5G2OLaTw4',
#   'c3jZIVNmGlQ',
#   'NgQUGllk5SA',
#   'UWz4LPyoSw4',
#   'XMJk2x1R8Ec',
#   '6qFBZQbphbA',
#   'wwijjQ8xuuQ',
#   'u04OahyztQI',
#   'Y3QgDin_-tA',
#   '1YxRIpOv36s',
#   'sjVMsvaCNa0',
#   'OcIfbAOBMhA',
#   'oGxVLeUrrY4',
# ...
#   'Vka2i6vufI4',
#   'sHmvfKaigJ8',
#   'Xy1Ac1wJjYU',
#   'k01Ug64Ird8',
#   'ZnSTu61OZZw',
#   't3wv70AKlWM',
#   'WdDbDX3z8A4',
#   'bRJ5O-yoew4',
#   '9Jw5uhKkjQc',
#   'NwPv4c8iiOA',
#   'QQ4aIZyxljY',
#   'yL3Z97CfXco',
#   'bzqVf0LO7lw',
#   'UQk3xOCi7mk',
#   'cx827tYXVhM',
#   'vS0dRoBY9TQ',
#   'IRyOulEI-r0',
#   'J-4Yr0HdCcc',
#   'S9g8Ct0aOmU',
#   'Z3bn-Qs1HOA',
#   'lwdM1RSh2CE',
#   'Utydmm5EF7M',
#   'qPrJgJorKMU',
#   'e-eHiGDIyMI',
#   'Qj7NgNqkyrg',
#   'K7stwfTI9u4',
#   'YlF8KJvR64w',
#   '0NwPAymVwy0',
#   'hT9H3wnDj0k',
#   'lSL4OKVYuDU',
#   'eCRKedOcXbs',
#   'fURpxOvAKLI',
#   'Pk33tDkiPkY',
#   'KJqLd5eBUWA',
#   'oe9g0i-TeMk',
#   'dhSr1WWBX4I',
#   'Y5uHBEQhtrw',
#   'PC-bOriXKp8',
#   'MAHXJCuh0xg',
#   'iKq2O0vEUzQ',
#   'h_bIUcx8y2I',
#   '1uOs66jM3Ts',
#   'XRgubknZwes',
#   'YiHRM-6S2fo',
#   'wxOxKatsW0Q',
#   'RU_4hMu19JQ',
#   'FgcjGNoECK4',
#   'hzz_eQtPVYI',
#   'iAhVMI7Ospw',
#   'Ni2MbR0nE90',
#   'aQMjBgLwhtw',
#   'LgMoPKGkhYg',
#   'nYEXZivpaaw',
#   'IkPkVRn-iq0',
#   'J-gbvtrZHX4',
#   'IOL_w3_PPrQ',
#   'OexMN1v-VLM',
#   '1zTTDUtoakg',
#   'CKtI-4q8IDs',
#   '9WujaEByUCc',
#   'KlEQJniLYA8',
#   'O3M8FpOq-gc',
#   '4Pls4TLZ9Gc',
#   'Y_RuusUf9IA',
#   'pAcSKokNdJc',
#   'jKVER8i1Ywg',
#   'XYxhZ8s8fto',
#   'kSkiJcX1gyk',
#   'Bk_5kNCbLJw',
#   'Zgsk25cuS3A',
#   'TAeir3mPBHk',
#   'mO33cFRtKk0',
#   'sUL09Yx3HS4',
#   '6WOKS4_WX2w',
#   '8yVS9JcdcYE',
#   'JJRfRnp6pyw',
#   'xhmLFRZnO7Q',
#   'i-jHruOiqa4',
#   'db8pZSJ4opg',
#   'rFTQLs9k7HQ',
#   '6sqSEWMkc8w',
#   'H09I2VIz0_4',
#   'EoCGlLs2UO4',
#   'e5q92SId06o',
#   'ItHuuyts5qs',
#   'jFaPb9ZReTE',
#   'BQQxyQPVFmg',
#   'tF9puthBhyc',
#   'qLnPjY5dxc0',
#   'Jwr4CY58G1E',
#   'gky_qOoJ_Ac',
#   '0Y74yXozT2I',
#   '3tLc9lcGUUY',
#   'MRJiQEXPNZE',
#   'pGSLmY1pjsQ',
#   'mPf717wnf-Q',
#   'NoLw8cWUSoQ',
#   '_KC3XiQm8_4',
#   '73PXVQlvLs0',
#   '1NnKxb1WBb8',
#   '3bMs567i0v8',
#   'PHkY8SKR2a0',
#   'MCU6NabAS4c',
#   'XdkT9NI2A7g',
#   'O0phoUG0-oY',
#   'IzrdVNIERaY',
#   '77dq0DkWVh4',
#   'a73yWOEQ7Wg',
#   'I8t0fPDLKZE',
#   'EgjTz_UBZGQ',
#   'HEA0wngZOzE',
#   'L_2KpgBfY-c',
#   'bgjq4e4iEFQ',
#   'ILfJjYR2XCI',
#   'qGT9gQQNMSU',
#   'Tg1CWeSpgWw',
#   'EJo_g7XYUOc',
#   'buTzPb5tzdI',
#   'UsaBYx2Z8gg',
#   'Eg_bIzJPlq4',
#   'qQ7TqrX51BE',
#   'SWsoV-_p0rY',
#   '3W_eu14R4-A',
#   'e30CMryrqew',
#   'Zl2gq_79mME',
#   'QjzFMNLf-dM',
#   'qhzv6vN4a3c',
#   '1TxbqSI17js',
#   'b6UF6VK9RVw',
#   'iK64wy0b2ic',
#   '150D2-7emAI',
#   'ShKBt1HqaQw',
#   '52uGEpaBM9c',
#   'VbXf-q9Al8Y',
#   'arLGa6Gf_xs',
#   '671ILAoZxAM',
#   'NykTmID9JuQ',
#   'HRzViWEARAs',
#   'B-tgDgt6eXU',
#   'IsPEPlK0ZU0',
#   'VreZ8FQuwHM',
#   '32-XsBC-bY8',
#   'wH9GKJWVc6A',
#   'fYsGXj_ZSAQ',
#   'ZkYmZUGoqOY',
#   'XuBVwBzl2gw',
#   'FEYeLxib7Ds',
#   '6-988U7za2k',
#   'rFHqUKO3Zks',
#   'QkUdHk_j-qA',
#   'k1799vkd_i0',
#   'EdBpxmSzPxE',
#   'ynaD9CZ7s2M',
#   'weZ4wNiF1H0',
#   '4lEUrJmnoww',
#   'rdh5D5mBUC4',
#   'Ozmlmlxr3NA',
#   'nKV6Xoj5jCA',
#   'cnuY9QUmKyQ',
#   'uo6EOeMjHSU',
#   'K824I5KpGb8',
#   'LevpHcd3gnc',
#   'EmjH6mkaVSQ',
#   '0CXRe3INYPM',
#   'AsKFeGQ2WKU',
#   'fEUu1JLg2vA',
#   'aJOtw4Nn1BQ',
#   '40L006ZPDug',
#   '4vTDKIQPWXw',
#   'UbRMQheXcw4',
#   'RdFaNEmjqKE',
#   '2c-xQbZELY4',
#   'MnEZdYP5v-o',
#   'z20wJkdKz98',
#   'Ni44FwTgvzo',
#   'ozpV7LyJ4YQ',
#   'u8-8PYURHdY',
#   'i0Q8-vV4vkE',
#   'mKf-gcr3w1c',
#   'J8jyb7f_vLg',
#   'tbzeCb8x7Eo',
#   'bJF8UEq7CZ4',
#   'vXqLim2Sh5U',
#   'Hh1ndISzZHw',
#   'jVk2k9FB4qY',
#   'HLaXEgzFucM',
#   'ZJaIHdyQV8I',
#   'uPqKsek8ceY',
#   '_HLtjsq33PY',
#   'ETLfRkVfZjM',
#   'hB0VSJfOX9k',
#   'QnnY4j-zASk',
#   '3yY4ai2L2BA',
#   'rExB3b_Px7c',
#   'VNtqYVpeP5g',
#   'LYRDrTGLhnk',
#   'Dx3HIGIaQlw',
#   'sPZhlCGB8AE',
#   'M5vbNtrA4po',
#   '9StxWhJLpPY',
#   't6kg7Itf68o',
#   'inSFmTVl-ME',
#   'VzMwX0v8kA8',
#   '9H8fjVRbE2Q',
#   'vEFuQtF4OIg',
#   'GMpbvXoYbfk',
#   'uklgrpnttJg',
#   'NSmEyRHSIFE',
#   'f9E09DtJHZM',
#   'eP_1XUqAaJQ',
#   'K5jjyjmIGKc',
#   '_4GrVWgrMHI',
#   'F8DeRlcs8bA',
#   'D_QYeiEkFfQ',
#   'hXlFu_bqjzQ',
#   's6wMA_FgPpI',
#   'VQQrRSL-DlI',
#   'fraiEvIcd9M',
#   'duvdjiUcCYQ',
#   'L-uykF0dCHY',
#   'okw4wvHCaqw',
#   'tkOIct3mN9g',
#   'yVv6kBZ60EM',
#   'Tj_jrrGPrCE',
#   'NBoqr9oEutg',
#   'uKQUbL6uW9Q',
#   'EosCGYihDAk',
#   'wQcFUmYse78',
#   'ISz6UM6KAC4',
#   '8RSO-gZjQdA',
#   'KpMQ7PSHlxM',
#   'qVRP46_IKyo',
#   'uX-u1C7hg0c',
#   'As9GivYPF1U',
#   '7WPDdoNWAEk',
#   '3y_vCQN5Lsw',
#   '2VVXFZoX1Fo',
#   'eDbJkLLyRxw',
#   'ljzTtkN-OHE',
#   'GlBtJDP39_4',
#   '9X1Yb0BBesY',
#   'LDzhENY80mY',
#   'SdGkw00fTdI',
#   'BJ-ta0mtaEw',
#   'hAgMLnme_DI',
#   'lz1IleKHQfM',
#   'pHTagjkeQck',
#   'kJ45r4GnzfY',
#   'lr2vvvbNFps',
#   't7dCTrZK7RA',
#   'uAdmpK8U0vs',
#   'oCaizMyMs7Q',
#   'JNzJv2Zjars',
#   '08OPWzGWNUI',
#   'iXIJBf8eeTg',
#   'wFzT9EiGoyY',
#   'yph7YlyTG8c',
#   'rlzbmDLQj2k',
#   'oBoCTaGbEz4',
#   'M9dk5Q_JgIY',
#   'FQm3jtG9ttI',
#   'zVLe1onI7yE',
#   'WasQ2iEUYo4',
#   'et9lkAS2_SM',
#   'MEDtmvTPVRQ',
#   'y2WuUNKq3_A',
#   'F9FSc1dwHqA',
#   '-ZIuUhzWLHs',
#   'EGZo-P2UWtg',
#   'HrwAx5A9D9w',
#   '__Y0rBwT1ag',
#   'BWaRuMWJ1uE',
#   'AVvZNRDAPyY',
#   'Gb0UmpOOtD4',
#   'iJwugUjw0jQ',
#   '32AC1UOzd1I',
#   '0J2r991ZI0o',
#   'zmoze8lu0-8',
#   'OYHfa4hSICI',
#   'BNLEtJ7bkSs',
#   'Q5t7875-IuM',
#   'pLiaLeKaZUo',
#   'i6B4TOwEUd4',
#   'yMQXKxgO2Ys',
#   'OPFb0Tt7owA',
#   'xWvIPhPprmA',
#   'JdcjoOlAIJ4',
#   'JdvO-NpMg0U',
#   'woFtYQR_9qA',
#   'G2kdkzDOlxs',
#   'BzD3wCaOwmI',
#   'QK_hcMfPuno',
#   'Yn2VPgKujGs',
#   'E9-m9ZC1_Ac',
#   'Weeoh9SI61E',
#   'smmRynkVDps',
#   'WYFEUERe8eg',
#   'pm-sBtsaIAw',
#   'buW0L4vMQWc',
#   'qaslr1EF6wQ',
#   '6Yk2STqECcU',
#   'RXmLjZniRXA',
#   '9nyXYwaYnE8',
#   'szPSu5R7HJk',
#   'XeC4ARwkUPk',
#   'CUTrDnlcrTg',
#   'Zlra5FqHAnI',
#   'ycmyVttQtWo',
#   '1tMAMxPQu8c',
#   'wFANHcYzcOs',
#   'mvFyJ-qY01U',
#   'NVIRfUfbmh4',
#   'wQssR6IUnT8',
#   'WRBLBIV2ZZI',
#   '2oipqhKV7zc',
#   'M3FKx-W0FRE',
#   'D7dxgakppjY',
#   'WcAZ--gQaqw',
#   'bHuhUtHcbf8',
#   '1bUM_phkMz4',
#   'Y0abyIgzXpE',
#   'AwTQu_qpPsM',
#   'pqTxRgN-j5g',
#   'hinHat6WV3Q',
#   '3bFMNf28cis',
#   'RBfUaDyptzI',
#   '0H0TgJGXDmE',
#   'XjE2yL1pebc',
#   'kXPh1g55t6Q',
#   'H2kj54dlTPU',
#   '-zHemZK0DHU',
#   'lc_koI-BcL4',
#   'hPk-_CdqKTw',
#   'J8Ej6eEUl2Q',
#   'wOpf9Zff8eU',
#   'Rd2SDYxnv1U',
#   'Kp8u4Ld6Xsk',
#   'HA_ZJ9mkysM',
#   '8E2QksviRAA',
#   '-dIMUvb7T2U',
#   'WdZUlnTqQfg',
#   'yegctLSFumg',
#   'dvvuKoHriPE',
#   'sTkv6wljaNU',
#   'Ohf9n0IQVdI',
#   'utQ54ucal34',
#   'Pi9P_w_M2Mc',
#   '04O5samNEC4',
#   'TBc0SpXFWy0',
#   'WtLanrOf-6o',
#   'JB8UUY4WxK0',
#   'VbWI3kcCCBM',
#   'q0rn3Z673HA',
#   'vrWXSMMLTMY',
#   'pzJxjYpnhYU',
#   '5aHybg9eKKY',
#   'KCf4zEK8ZZo',
#   'Myfn8gPMKPY',
#   'IjQFkrp0I9Q',
#   'Lvv-5vgBXtY',
#   '0fQX3q_3Qqg',
#   'HAKC-g0H9X8',
#   '0c08eiLmD8Q',
#   'tJ8fAYTywTE',
#   'zuKqHw3vsg8',
#   'ETr1OzXbdwY',
#   'meznCmCr3Qk',
#   'xZcqiz8XBig',
#   'u5rGKDSvCDc',
#   'LqrBBA6n5Ao',
#   '_--EY4qcgQ4',
#   'U4blYDyYP6k',
#   '8KT0cy0f67k',
#   'YoVMWEn1cyA',
#   '6_PeE8cR7A4',
#   'gNAsJphgzEU',
#   '3csoIRz9HFQ',
#   'BTk74JHBFoU',
#   '9CMp7Hb1-y0',
#   '0wOaSegX_7Y',
#   'BQCuKnFIg6o',
#   'dv9c5mxuQRw',
#   'Iz3g5-JGI8s',
#   'qVr7iuce_Ak',
#   '3EDCA2lL2fg',
#   'iYmE1RkGWDo',
#   'muucfBPQjwE',
#   'dXNX6mEJic0',
#   'NMuaygebfeY',
#   'mu--zExTMZM',
#   'WqLTo_zERLw',
#   'VflbnEv1Rus',
#   'RBbLdtNm30M',
#   'jVG92EtQzeQ',
#   '3r_ygmlZwZs',
#   'E7ggs24wKrI',
#   'mUHeg9KbzjI',
#   'tbox5Y0vun4',
#   '8JF_U8dtu_o',
#   'SFPT7UmTjj4',
#   '8Zmc61xMZ6M',
#   '5koHPcqGJRw',
#   'vf8ElF2uezM',
#   'dpokr-_ycGk',
#   'diUiZR3vGkU',
#   'aHz1Eck30wc',
#   'NbXQipyZtZc',
#   'BwyRXyZ2XB8',
#   'kr3txrcCLjw',
#   'hMFNW-AXi4s',
#   'hGjR4vHudHo',
#   'rGf3gOt4zOg',
#   'TPDlWSzaEJw',
#   'pysOXDbXz3g',
#   'GRlzR_o0m9g',
#   'IuElR4JBBMM',
#   'rYoJFEv-f_8',
#   '7t_a7Jp6VLA',
#   '0ZlWmXFDAN0',
#   '9OAJqZFVvZE',
#   'Bx8K7gbuvQY',
#   '2hKj04HCh6w',
#   'u2IGi4RjaH8',
#   'id5pGJPXsA0',
#   'KfHadHFQ2U0',
#   'Ej53Lkv3zrE',
#   'wsnYakn-IHY',
#   'JNsw9mqF-mk',
#   'QD3ynQ-FX-4',
#   '6f41CI3PMrk',
#   'qKhjn7gBWKw',
#   'fJ8alNJQjqc',
#   '3mTpVQb51wM',
#   'xuOStmj9eVU',
#   'K6F3oZBkgDo',
#   'SsdQL4dfLfs',
#   '2b4W1SY93pQ',
#   'mulcJWx83LM',
#   'xtZvXuevVE0',
#   'N6R0X_3GEXo',
#   'ccGWTNPxM7c',
#   'jXtT_tB4Ggw',
#   'TKje6WSyOc0',
#   'jOVUEPypssc',
#   '3BFAqkSGT-A',
#   'S1WPF3hARJA',
#   'e98kralasTw',
#   'i9XVdS5Eupc',
#   'B-67iqZbY0g',
#   '69LwEqmrWGY',
#   'Ec3iG9yNB3w',
#   '1jxHmLZVKZM',
#   'vOEmMnmf6w0',
#   'r_YiUboOvBU',
#   'W39Da3jhFwM',
#   'ZvAkYXrYVgU',
#   'Y3CeKq6MalQ',
#   '7EgilPjwBE0',
#   'nFk_g_JRPAg',
#   'wkBbwlaKGeM',
#   'u8ayY7xO6-E',
#   'Ui3UU31LQ4k',
#   '5-C-CbcWnW4',
#   'A_YDx9RyQeg',
#   'R8FNDmn5Okc',
#   'O0CFooWH45A',
#   'VlQKmn5RRh8',
#   'dRJhpJawx7s',
#   'eJMg8Db9eD0',
#   'kXhuKovKcx8',
#   'MtiXcDVp4cg',
#   'MHyH9osc-uk',
#   'xeIph1ihHAQ',
#   'Qf2b_i2DwPg',
#   'nxz92hC2BG4',
#   'C_BK5tJW8AY',
#   'YXSn8PjueTI',
#   'XjV60fsqvcU',
#   'vIPmmD49jZQ',
#   'IkiPFioSCOw',
#   '1U5eClO-LUw',
#   'XC6COv9pOlI',
#   'zKGcvw6R4x8',
#   'cW6HxcBMysc',
#   '9HNb4LjL344',
#   '_3F4uwBzgDs',
#   'WuMSbjZ2vIQ',
#   'LZOAj7y9SxU',
#   'j6Mbjw85GUM',
#   'BbGJOUX2sK4',
#   '-5DapGwBTAg',
#   'IPCI5HvsuE4',
#   'Hbm2kjDt8IY',
#   'Xx1dFXg5okw',
#   'GD6aLxnuoPE',
#   'UEMD_VRs5hI',
#   'VfAOVQlJYFs',
#   'k51RFS9STOQ',
#   'UdVa1C0wx-o',
#   'buU3mFiF9EE',
#   'kv8ZKzX1Qqk',
#   'Gt-SpGR0094',
#   'tHi4dziexnU',
#   'DXx8Vc4CYKg',
#   'RBlqXaQkuUk',
#   'v3L35dVH40g',
#   '8eFQEQgwkPo',
#   'PEwnxbjgfyg',
#   '9XXRCUAluXA',
#   'uDtvib1C034',
#   'UNl3mUqvZG0',
#   'gAgC02VFceQ',
#   '76Ob7vBt1OI',
#   'QY0i7ZAUWk8',
#   'FQ_7FwMfyv8',
#   'vDNCkfZLUSE',
#   'th9_EN6Tem0',
#   'q0VLnzHm6ao',
#   'EUtvF4e7m1c',
#   'MVUdQINHFm8',
#   'r6uAB1IxJwE',
#   'MGAE40nEv60',
#   'POAnY7lpWh4',
#   '4f-MUxsCKWo',
#   '7SYEW7B-k1A',
#   'FCgvq36evBA',
#   'dowXKSh8tAc',
#   'r135Jhg4F7Y',
#   'wWcMnDNUdac',
#   'R-rn_H9fJec',
#   '8HTQCsoHw9c',
#   '96NzHAnVB8M',
#   'EM144_1Faco',
#   'rd7k7MXfxUU',
#   'CB8TJhokIjE',
#   'mH_BC0pO-3s',
#   'hCmXVzXxdBk',
#   'b1Ob2K4L7ns',
#   'qaj8zwKs6Ck',
#   'vRD8PgEv6w4',
#   'GdlOVjJiSl0',
#   'PhNapZQgbsc',
#   '-AzSpuFIt1U',
#   '-KR7zN68O7Y',
#   'cAednnwuSrY',
#   'p0jTIcNYb6o',
#   'da_RhPTeA6w',
#   'Obc4kdHGqt0',
#   '5bFeQTLovI0',
#   'Wv3Qi0uWS1s',
#   'cajikqCTbkU',
#   'N2CViI88KS0',
#   '6rzZHa4iorQ',
#   'zFBURrdfo5k',
#   '3vQgYRwvcUY',
#   'ovcHEOd0Ul8',
#   'vsQlEeBd2hE',
#   '2zxwckgPSWY',
#   'hsGtQo_dVz8',
#   '2-br02Fh2WQ',
#   'HS00s0T0_wg',
#   'KJcojUepZUU',
#   'Kke7P8TO9Ps',
#   'cZXttF2QbJg',
#   'VrJ5wqbCsHo',
#   'np9xNcOSs9k',
#   'XhD50fTaV1k',
#   'lZg2JIVHOBg',
#   'q4fsUO2drho',
#   'tB6_OSrv4D0',
#   '205I0dIOqyw',
#   'AxWg0wCbzM8',
#   'HfATalropzk',
#   '8t5vOIFsjaU',
#   'J5vCsRUzSSY',
#   'b_LBFwuRsR4',
#   'NdBFThFyG4Y',
#   '9oGcA28unhQ',
#   '1OSVfcuXMmg',
#   'eo2QMPmuitY',
#   '3fJwmkccjrw',
#   'e_9MJt5-6NA',
#   '9K81YthpCjs',
#   'lQiXA56WvKc',
#   'ZMZ5mfxvZzs',
#   'CoO05IlB9pE',
#   'VmPbWHxkboQ',
#   'tU7gHGRwBS0',
#   'xOF8m8DOR0I',
#   'LwAI2B7WHaQ',
#   'CBoGcUQoWic',
#   '_Mlwm5tSVhw',
#   'H4xBJwWy4bM',
#   'uxmx1DoInH0',
#   'Ebi-KWZlGug',
#   'QEFIYdI8ROc',
#   'XmDnyP_jKyk',
#   'vNbE6LN6ivM',
#   'SdhR_-A9Bx4',
#   'XEhHvk3THt4',
#   'USa59PwjwHw',
#   'MXiesFlKOVE',
#   '7ZoUfdpmpGM',
#   'LPPLeDvUazQ',
#   'mQvspV1KgLs',
#   'JO3aQa0n-iQ',
#   'Bb4i6SR6z_4',
#   'NF00jC6evoY',
#   'yDPQG4-tOdM',
#   'IQn2SwH1oBc',
#   'Lvhq79jEDt0',
#   'smSquQxjDBk',
#   '3k4vUBSYUXg',
#   'tYPj6YgcU_w',
#   'liMf7W8MIkc',
#   'tzdAUW7hUjY',
#   'eDKyHLGLCjY',
#   'c-A3D80EmP8',
#   'VvavPhwE6GI',
#   '8nCUANPCqfQ',
#   'R0lQm9kLCwQ',
#   'i1sVMJUmdYE',
#   '2d-Znrner8Q',
#   '3boPmMAMoAw',
#   'LUf3whIUStU',
#   'WBAJAC1ctPM',
#   'IGb180VHPD8',
#   'mOSIee4z5qI',
#   'oWpIZaURDd8',
#   'GrrDJGyYEpk',
#   'w9ukp8E0qRY',
#   'FaV-pC_0VoU',
#   'Q_xHQjSixzM',
#   'N7Dod-RZ-Y8',
#   'n8ya4yhz1ok',
#   '17KtsLIZ_Zc',
#   'kkqyS04zU4E',
#   'L2IHZlTFou8',
#   '_MFa25qSWsc',
#   '1JfVV9Ovi1k',
#   'BAvCNkuLqsg',
#   'NImS5zdTXzE',
#   'Rvs8rg1W_vc',
#   '3aa6Pc7gzmM',
#   '2lCrzrOduwQ',
#   'SFG3indASIo',
#   'wT4uP9sYjwA',
#   '1a0emHKWteI',
#   'U8cy4EHYkyU',
#   'wFdx8esj1r8',
#   'Yov4cRjiSvs',
#   'cDA0GahiSNA',
#   'QiZIBrDT4uA',
#   'pAAEAorv19k',
#   '73y30Z7VBqA',
#   'KN0X3Wr_stw',
#   'NfwCWwEh2C0',
#   'hDehGTfGdWs',
#   '9mnIdDQxKQs',
#   'yt1CEkx91gI',
#   'ugkUx-CNFnU',
#   'tCiPvc5_CWE',
#   'dFy-LRo5mlQ',
#   'RQmhmy3Lmnc',
#   '2YbTZ3zWlS4',
#   'l6-thfmIcE0',
#   'REMzpvShLGM',
#   'Dy5QQz4fRjs',
#   'JJ5WRvnDfQw',
#   '8_CY4SIL-vA',
#   'e-6zOBKX-cg',
#   'MsymjX874CY',
#   'BlfrhrHFK-w',
#   '6c1mBgZrUfE',
#   'Eu7Rp46WTNc',
#   'swmDXSgQCls',
#   'c_YyKZbAoiE',
#   'ji4QNbLlP1M',
#   'MW5iivcoJl4',
#   'yOiCxhnDrfg',
#   'b-6CSg_Gmxk',
#   '2FC0nfwBGP0',
#   'uRBg8z8lm6M',
#   'pE1GKC1oW1E',
#   'S0OiHG8ciLU',
#   'oa4gvIkBfuY',
#   'p2bKx9_qkf4',
#   'EYSkOItw-3Q',
#   'jFwELodXCBk',
#   'ZujUv3Ph8k8',
#   'OSB2g83fE3c',
#   'HHsvFQ0KP0U',
#   'QoTZQMq8-28',
#   '1nYgrcwfFTI',
#   'dEcciJpfDlc',
#   'l5YHEJUFNoI',
#   'utVlTAu2avk',
#   '4S_cUiR7_iA',
#   '9UBsMgIf2oA',
#   'XTXSE5Z8UpQ',
#   'C6BOzbs__88',
#   'Djvpz1hNK5U',
#   'Yn_HonwcCtI',
#   '2byl9IHh5lI',
#   'QlZpdaYTexo',
#   'uO693NxHUg4',
#   ...],
#  'Pick Up Limes': ['dyfe2JnVLxk',
#   'Y-uNCSo9Zns',
#   'LurJFaws4vE',
#   'j6Cj7IQvGXM',
#   'SzG3OnpXwLc',
#   'VxTfRrXOKC0',
#   '9we4K9AvLH8',
#   '93O0d5a2wMo',
#   'ZCfm-wvlLxI',
#   'lxz_gqXVnBY',
#   'hqd8i8eXDsQ',
#   'ERysyFbJH7w',
#   'CIYFIBbuOU8',
#   '6DWTYEQoxmw',
#   'EwLGqrH0ZrM',
#   'ARCsZOK8Xgs',
#   'wiqjtX6kKUQ',
#   'FRDXhFVmlUg',
#   'OPP0DPiMOP0',
#   'bd20rwynvb0',
#   'KW2StiK3Rjc',
#   'WI_9NoMof7s',
#   'FZ7IJWbs9vo',
#   'QKj6DRKOelE',
#   '9iqQJIfMAnU',
#   'WqNmhHdOEfU',
#   'O6eWdiaBLqc',
#   '7HM6Ha43wPg',
#   'AQ_MZG83Wls',
#   'QV-B0S_yuc4',
#   '8CqwjlaKqns',
#   '1-VFShuFJXQ',
#   'xMdz4-AiYA4',
#   'Cl_bNkVzdQg',
#   'vvm9na0x2_Q',
#   'ztltfnNNth0',
#   'uBzsHhp8Fsg',
#   '0wNJSPSHedk',
#   'N3f1PfRL2h0',
#   'e5pJmSmT6ds',
#   'wA2djbEg81I',
#   '45awieDmjVQ',
#   'UTBlCRy3Mo0',
#   'VUz3FIFYLG8',
#   'DrYP9V4f8Ng',
#   'nJ05FbCiO1k',
#   'd_qxjYCHI74',
#   'ZBKUqc_ICpg',
#   'I8IK3ZeWOjU',
#   'h-1icJainvo',
#   'tQeZIvrong8',
#   'WmFKNIo_FXA',
#   '1Vx98u05R8s',
#   'kyKo7h-NvpM',
#   'jX-mhRo7Hww',
#   '_Z0RacfZ0r8',
#   'OCyQHItH5H0',
#   'h_zc4u4zL2Q',
#   '77G2CE5sYhM',
#   'tIeW99jJX2A',
#   'yQmo3Z_xSlM',
#   'rctONIZJxh8',
#   '_bmppyU3TnA',
#   'XulBKrrRC3k',
#   'cD72O6IJUBE',
#   'pvDcccfyzwk',
#   'EIDi42qEVJI',
#   'XguZA4d9Tfw',
#   'svjxTwTQ9OA',
#   'aje9UGNi_l0',
#   '6y6YeD2m9RY',
#   'FZq-w1t9lyw',
#   'vEeUxE4txs8',
#   'zrn6IP0GyOs',
#   'PFwc8BfSvCw',
#   'N20c-FP-npY',
#   'tEIlJidvqEI',
#   'u4zbbQiPpaY',
#   'WMblgMbNLhM',
#   'hcOycPWR7is',
#   'ZVneOn6b_Ks',
#   '8kLAGblVlMM',
#   'RYuMxWP-Wf0',
#   'Ral6E1SHNbE',
#   'S1OJ3U2T4PY',
#   '0e3M5Jyh6Z8',
#   'FxtEz3ztn4A',
#   '9SKlOqs4a48',
#   'PMjreZH1bzU',
#   'J1LW1Nz0pd4',
#   'BXYfOAe3On0',
#   'TskyrDTyWiI',
#   'WYgsX-FonfY',
#   'hxlO_Facuo4',
#   'CiCPO1cnA-U',
#   'CPbKkb1hn7I',
#   '_ME1dEXcT_I',
#   'KvJOZE15e3s',
#   'oIvCALCtQls',
#   'WcB1rZ_lL1U',
#   'G3h5edhUml0',
#   '8KEtFdVpFZQ',
#   '7Pv2VwjuRz8',
#   'jFHHE2YcJ3k',
#   'Jjub18AHC9M',
#   'DNuSSCtVW78',
#   '8kU7d-kk8-g',
#   'ziUq2NJI-Ps',
#   'PhYRRpHienM',
#   'VH3VFi9C4Z0',
#   'gKPwACJEnAA',
#   'pc3M3cH6iJo',
#   'wsUl2ofKuAQ',
#   'Jh5oX0VRnzk',
#   'rWfwPTv5jy0',
#   '0Kgi-H2W7Hk',
#   'MC4OAeC6qe8',
#   'Bcnet2jD_II',
#   'OjBsyL5odg0',
#   'NOgPQvUWfHk',
#   'IDLEQuejwU8',
#   'ZK5VUuxGYr0',
#   'BaFK17OyXSk',
#   '__VRtNQ0c1M',
#   'YmwCJsieHPs',
#   '6ZsuGfxIUx8',
#   'u_URtsY1FGg',
#   'Vo1m2cK15_c',
#   '3uiaaiugNdE',
#   'qziBpNkox3w',
#   'uVyQD--miGs',
#   'W4CpxgJb644',
#   '7xw7HGS7PIw',
#   '_sVmBv8Pj4Q',
#   'YAwanemlagU',
#   'WUhsyK9Azj0',
#   '0jyxdYucQCg',
#   'ewNoaIqr7ms',
#   '76SiK1mu3uc',
#   'j5TFJThFA2c',
#   'Y-txjbuLX9k',
#   'x3nIBdywwnY',
#   '5Db7SdFvu_E',
#   '6t_qxX7opvA',
#   'hGOX2jxht2A',
#   'KQkuE_gwVGQ',
#   'nbAwOS1FZIw',
#   'yrR_7hlEGyw',
#   'RYAsJy6j8d8',
#   'y2PL4gNffBI',
#   'LZhnCxG5c6s',
#   'K9rJ2A1S_I0',
#   '7UDx1RF9Oho',
#   'JtoylbJcH9g',
#   'eI91-UZpJr8',
#   'HYvA-vMf708',
#   '8u9ABp1f3IE',
#   'mI7WMgsR3WQ',
#   '8a170TTaPt0',
#   '2y9St1EarLA',
#   'MMq9Sxp9GFo',
#   '9liz4MHs0i4',
#   'oLSl_quyKDM',
#   'Q66OMce-vl8',
#   'c-klSziwUng',
#   'pZiuqB0daBc',
#   '2o-aBMdasQQ',
#   'I_lWPKdFEP4',
#   'YCaoZvShiJc',
#   'e9XrgdvFA0c',
#   'A3pJ6gaenW0',
#   'SCphxWFaWIQ',
#   'FBFy7PpH5Do',
#   'VQa6ivDsL-M',
#   'FEkwz0XuHkY',
#   'V5Fsvuzgkj0',
#   'M8GhWgy5g_8',
#   'nIYrRNklra8',
#   'W8mkksk1Ouc',
#   'lLMXM3_0opE',
#   '-9R4EBW1QeU',
#   'IUtv4IxVItU',
#   'cXgLFgH37OM',
#   'tosdybi0iL8',
#   'IG_UdqQMH4w',
#   'ZZLCnCfzirc',
#   'zFotlhvCzWc',
#   'KytbeQzI7P0',
#   'ojFLLEdXIXk',
#   '4dzsrT_pzC0',
#   '24IDJfPCHZM',
#   '649tA4lkXuI',
#   'yG_4BR08y8o',
#   'sFVAVMHOYLA',
#   'RPosXpVuqVo',
#   'cpUnjQV-Chw',
#   'JoL5ukBTwcY',
#   '0eKD-mDa3CA',
#   'oj0yH6M4x_w',
#   'KQOAVZew5l8',
#   'xNzZqVUl28E',
#   '46jVgjvSTRo',
#   'vQOvw-vjV4k',
#   'x9P4R7CRX5M',
#   'CnV1KDMSOxQ',
#   'vgSzFmpqNdw',
#   'HhLIDmKqbl0',
#   'OJxMsypwnqg',
#   'ZW9f3rYKoIY',
#   'pBTRu80BXls',
#   'UjZwTDWxhbg',
#   '95qsSITM3_Y',
#   'cx_veZygQkU',
#   'kYuYwMAqeqw',
#   'GTmvOiW3YVU',
#   '8Cq19bdJ2nI',
#   'CaItdegkoNE',
#   'VYziZLlAMSI',
#   'DtZ1EjV0EEw',
#   'wWoADZNVBu4',
#   '8poA6VWb140',
#   'EWwi6MoEARc',
#   'aI2-EFnZNXY',
#   'zu5yeOxjPXs',
#   'cnXJtEhUlDU',
#   'LD7IKfNdMrY',
#   '9o0wiVEPJco',
#   'EnAlwMfB2S0',
#   'YF6gNnYtE9A',
#   'KROKdQupMeY',
#   '7uK7KBO_SUI',
#   'Miay0QvOUKU',
#   'IHsVwG9memg']}

# %% [markdown]
# ## Function to get video details

# %%
def get_video_details(youtube, video_ids):
    all_video_stats = []
    
    for i in range(0, len(video_ids), 50):  # YouTube API allows max 50 videos per request
        request = youtube.videos().list(
            part="snippet,statistics",
            id=",".join(video_ids[i:i+50])
        )
        response = request.execute()

        for video in response.get("items", []):  # Prevent KeyError if 'items' is missing
            video_stats = dict(
                Title=video["snippet"]["title"],
                Published_date=video["snippet"]["publishedAt"],
                Views=video["statistics"].get("viewCount", 0),  # .get() to handle missing data
                Likes=video["statistics"].get("likeCount", 0),
                Comments=video["statistics"].get("commentCount", 0)  # Removed 'dislikeCount'
            )
            all_video_stats.append(video_stats)
    
    return all_video_stats

# %%
#Youtube data visualization
import matplotlib.pyplot as plt
import seaborn as sns


# Number of videos per category
plt.figure(figsize=(10,6))
plt.style.use('_mpl-gallery-nogrid')


unique_categories = video_data['Category'].nunique()
palette = sns.color_palette("Set3", unique_categories) 


sns.countplot(y='Category', data=video_data, order=video_data['Category'].value_counts().index,palette=palette, hue='Category')
plt.title('Number of videos per category')
plt.show()

# %%
print(video_data.columns)
# Out:
# Index(['Unnamed: 0', 'Title', 'Published_date', 'Views', 'Likes', 'Comments',
#        'Category'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Load dataset
video_data = pd.read_csv('youtube_data.csv')

# Print column names for debugging
print(video_data.columns)

# Ensure correct column names
if 'Categories' not in video_data.columns:
    print("Error: 'Categories' column not found!")
else:
    # Convert Likes to numeric
    video_data['Likes'] = pd.to_numeric(video_data['Likes'], errors='coerce')

    # Drop NaN values (if any)
    video_data = video_data.dropna(subset=['Likes', 'Categories'])

    # Sort data by Likes for better visualization
    video_data = video_data.sort_values(by="Likes", ascending=False)

    # Set figure size
    plt.figure(figsize=(12, 6))

    # Create bar plot
    sns.barplot(x='Likes', y='Categories', data=video_data, palette="viridis")

    # Title and labels
    plt.title('Number of Likes per Category', fontsize=14)
    plt.xlabel("Number of Likes")
    plt.ylabel("Category")
    plt.grid(axis="x", linestyle="--", alpha=0.7)

    # Show plot
    plt.show()
# Out:
# Index(['Unnamed: 0', 'Title', 'Published_date', 'Views', 'Likes', 'Comments',
#        'Category'],
#       dtype='object')
# Error: 'Categories' column not found!

# %%
video_details = get_video_details(youtube, video_ids)

# %%
video_data = pd.DataFrame(video_details)

# %%
video_data['Published_date'] = pd.to_datetime(video_data['Published_date']).dt.date
video_data['Views'] = pd.to_numeric(video_data['Views'])
video_data['Likes'] = pd.to_numeric(video_data['Likes'])
video_data['Comments'] = pd.to_numeric(video_data['Comments'])  # Fix: Use 'Comments' instead of 'Dislikes'
video_data
# Out:
#                                                  Title Published_date   Views  \
# 0                 The greenest pasta you’ve ever seen!     2025-03-12  108823
# 1                          How to REALLY chop an onion     2025-02-28  346622
# 2               The secret to making tofu irresistible     2025-02-21  320510
# 3                The truth about "the perfect partner”     2025-02-12  433904
# 4    Flakey pastry you MUST try (just 7 ingredients...     2025-01-31  135863
# ..                                                 ...            ...     ...
# 228                    HOMEMADE GRANOLA » quick + easy     2017-01-19  700365
# 229          HOW TO MAKE A SMOOTHIE HEALTHIER » 5 ways     2017-01-17  589179
# 230  CHOCOLATE & HAZELNUT MILKSHAKE SMOOTHIE » heal...     2017-01-14  262254
# 231  COLD-BUSTING GREEN SMOOTHIE » immunity boostin...     2017-01-11  191819
# 232  RUBY RED GREEN SMOOTHIE » pre- or post-workout...     2017-01-09  264377
#
#      Likes  Comments
# 0     7068        92
# 1    17812        71
# 2    18151       128
# 3    28316       217
# 4     6674        62
# ..     ...       ...
# 228  17812       331
# 229  25934       392
# 230   7229       109
# 231   4606        62
# 232   5918       131
#
# [233 rows x 5 columns]

# %%
top10_videos = video_data.sort_values(by='Views', ascending=False).head(10)

# %%
top10_videos
# Out:
#                                                  Title Published_date  \
# 152           HEALTHY EATING HACKS » + printable guide     2018-12-19
# 218      QUICK VEGAN BREAKFAST IDEAS » bento box style     2017-03-23
# 200  HOW I CUT & LAYER MY HAIR AT HOME » diy long l...     2017-08-07
# 113  Plant propagation for beginners » 5 indoor plants     2020-04-10
# 121  Minimal bullet journal setup » for productivit...     2019-12-29
# 154          5 meals I eat each week » vegan & healthy     2018-11-20
# 207     BEGINNER'S GUIDE TO VEGANISM » how to go vegan     2017-05-25
# 20                  Why THIS is my favourite cuisine 💛     2024-04-24
# 216  VEGAN SCHOOL LUNCH IDEAS » healthy + easy (ben...     2017-03-29
# 212     HEALTHY MORNING HABITS » + printable checklist     2017-04-18
#
#        Views   Likes  Comments
# 152  8850956  341843      6027
# 218  8187126  276242      3459
# 200  7877839  154129      4137
# 113  6781289  200084      4226
# 121  5707763  202073      3289
# 154  5348754  171987      3740
# 207  4945489  203894      7840
# 20   4823722  196111      1676
# 216  4803216  188260      2432
# 212  4740147  156701      3303

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

video_data = pd.read_csv('youtube_data.csv')

# Set figure size
plt.figure(figsize=(15, 6))

sns.barplot(x='Likes',y='Category',data=video_data)
# Title and labels
plt.title('Number of Likes per Category')
# Show plot
plt.show()

# %%
! pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\abhishek niraj\anaconda3\lib\site-packages (2.1.4)
# Requirement already satisfied: numpy<2,>=1.23.2 in c:\users\abhishek niraj\anaconda3\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\abhishek niraj\appdata\roaming\python\python311\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\abhishek niraj\anaconda3\lib\site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\abhishek niraj\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\abhishek niraj\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
# !pip install kaggle
# Out:
# Requirement already satisfied: kaggle in c:\users\abhishek niraj\anaconda3\lib\site-packages (1.7.4.1)
# Requirement already satisfied: bleach in c:\users\abhishek niraj\anaconda3\lib\site-packages (from kaggle) (4.1.0)
# Requirement already satisfied: certifi>=14.05.14 in c:\users\abhishek niraj\anaconda3\lib\site-packages (from kaggle) (2024.2.2)
# Requirement already satisfied: charset-normalizer in c:\users\abhishek niraj\anaconda3\lib\site-packages (from kaggle) (2.0.4)
# Requirement already satisfied: idna in c:\users\abhishek niraj\anaconda3\lib\site-packages (from kaggle) (3.4)
# Requirement already satisfied: protobuf in c:\users\abhishek niraj\anaconda3\lib\site-packages (from kaggle) (4.25.6)
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\users\abhishek niraj\appdata\roaming\python\python311\site-packages (from kaggle) (2.8.2)
# Requirement already satisfied: python-slugify in c:\users\abhishek niraj\anaconda3\lib\site-packages (from kaggle) (5.0.2)
# Requirement already satisfied: requests in c:\users\abhishek niraj\anaconda3\lib\site-packages (from kaggle) (2.31.0)
# Requirement already satisfied: setuptools>=21.0.0 in c:\users\abhishek niraj\anaconda3\lib\site-packages (from kaggle) (68.2.2)
# Requirement already satisfied: six>=1.10 in c:\users\abhishek niraj\appdata\roaming\python\python311\site-packages (from kaggle) (1.16.0)
# Requirement already satisfied: text-unidecode in c:\users\abhishek niraj\anaconda3\lib\site-packages (from kaggle) (1.3)
# Requirement already satisfied: tqdm in c:\users\abhishek niraj\anaconda3\lib\site-packages (from kaggle) (4.65.0)
# Requirement already satisfied: urllib3>=1.15.1 in c:\users\abhishek niraj\anaconda3\lib\site-packages (from kaggle) (2.0.7)
# Requirement already satisfied: webencodings in c:\users\abhishek niraj\anaconda3\lib\site-packages (from kaggle) (0.5.1)
# Requirement already satisfied: packaging in c:\users\abhishek niraj\appdata\roaming\python\python311\site-packages (from bleach->kaggle) (23.0)
# Requirement already satisfied: colorama in c:\users\abhishek niraj\appdata\roaming\python\python311\site-packages (from tqdm->kaggle) (0.4.6)

# %%
#!kaggle datasets download -d rmisra/news-category-dataset

from kaggle.api.kaggle_api_extended import KaggleApi
api = KaggleApi()
api.authenticate()

api.dataset_download_files('rmisra/news-category-dataset',path='./',unzip=True)
# Out:
# Dataset URL: https://www.kaggle.com/datasets/rmisra/news-category-dataset

# %%
import os
print(os.listdir())
# Out:
# ['.ipynb_checkpoints', 'cleaned_data.csv', 'data', 'Kaggle.ipynb', 'kaggle_data.csv', 'news-category-dataset', 'news-category-dataset.zip', 'news_category.csv', 'Video_Details(OnlineStudy4u).csv', 'Video_Details(Vox).csv', 'youtube_data.csv', 'YT-Analysis-project.ipynb']

# %%
# Install kaggle package if not installed
# !pip install kaggle --quiet

# Import Kaggle API
from kaggle.api.kaggle_api_extended import KaggleApi

# Authenticate
api = KaggleApi()
api.authenticate()

# Download and unzip the dataset
dataset_name = 'rmisra/news-category-dataset'  # Make sure this dataset exists on Kaggle
download_path = './'  # Change this if you want to save to a specific folder

api.dataset_download_files(dataset_name, path=download_path, unzip=True)

print("Download complete. Files are saved in:", download_path)
# Out:
# Dataset URL: https://www.kaggle.com/datasets/rmisra/news-category-dataset
# Download complete. Files are saved in: ./

# %%
import pandas as pd

# Define the full file path
file_path = r"C:\Users\Abhishek Niraj\Revature\news-category-dataset\News_Category_Dataset_v3.json"

# Load JSON file into Pandas DataFrame
df = pd.read_json(file_path, lines=True)

# Display first 5 rows
print(df.head())
# Out:
#                                                 link  \
# 0  https://www.huffpost.com/entry/covid-boosters-...
# 1  https://www.huffpost.com/entry/american-airlin...
# 2  https://www.huffpost.com/entry/funniest-tweets...
# 3  https://www.huffpost.com/entry/funniest-parent...
# 4  https://www.huffpost.com/entry/amy-cooper-lose...
#
#                                             headline   category  \
# 0  Over 4 Million Americans Roll Up Sleeves For O...  U.S. NEWS
# 1  American Airlines Flyer Charged, Banned For Li...  U.S. NEWS
# 2  23 Of The Funniest Tweets About Cats And Dogs ...     COMEDY
# 3  The Funniest Tweets From Parents This Week (Se...  PARENTING
# 4  Woman Who Called Cops On Black Bird-Watcher Lo...  U.S. NEWS
#
#                                    short_description               authors  \
# 0  Health experts said it is too early to predict...  Carla K. Johnson, AP
# 1  He was subdued by passengers and crew when he ...        Mary Papenfuss
# 2  "Until you have a dog you don't understand wha...         Elyse Wanshel
# 3  "Accidentally put grown-up toothpaste on my to...      Caroline Bologna
# 4  Amy Cooper accused investment firm Franklin Te...        Nina Golgowski
#
#         date
# 0 2022-09-23
# 1 2022-09-23
# 2 2022-09-23
# 3 2022-09-23
# 4 2022-09-22

# %%
df.to_csv(r"C:\Users\Abhishek Niraj\Revature\news_category.csv", index=False)
print("CSV file saved successfully!")
# Out:
# CSV file saved successfully!

# %%
kaggle_data = pd.read_csv('news_category.csv')

kaggle_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 209527 entries, 0 to 209526
# Data columns (total 6 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   link               209527 non-null  object
#  1   headline           209521 non-null  object
#  2   category           209527 non-null  object
#  3   short_description  189815 non-null  object
#  4   authors            172109 non-null  object
#  5   date               209527 non-null  object
# dtypes: object(6)
# memory usage: 9.6+ MB

# %%
kaggle_data.dropna(subset = ['headline','short_description','authors'],inplace= True)

kaggle_data = kaggle_data.drop(columns = ['link','short_description'])

kaggle_data.head(100)
# Out:
#                                               headline       category  \
# 0    Over 4 Million Americans Roll Up Sleeves For O...      U.S. NEWS
# 1    American Airlines Flyer Charged, Banned For Li...      U.S. NEWS
# 2    23 Of The Funniest Tweets About Cats And Dogs ...         COMEDY
# 3    The Funniest Tweets From Parents This Week (Se...      PARENTING
# 4    Woman Who Called Cops On Black Bird-Watcher Lo...      U.S. NEWS
# ..                                                 ...            ...
# 108  FEMA Director Says It's ‘Too Early’ To Tell Wh...      U.S. NEWS
# 109  Pakistan's Largest Natural Lake Is Rising To D...     WORLD NEWS
# 110  Uvalde Children Grapple With Trauma After Scho...      U.S. NEWS
# 112  'The Osbournes' Will Return In British Revival...  ENTERTAINMENT
# 114  Fuel Leak Ruins NASA's 2nd Shot At Launching N...        SCIENCE
#
#                                          authors        date
# 0                           Carla K. Johnson, AP  2022-09-23
# 1                                 Mary Papenfuss  2022-09-23
# 2                                  Elyse Wanshel  2022-09-23
# 3                               Caroline Bologna  2022-09-23
# 4                                 Nina Golgowski  2022-09-22
# ..                                           ...         ...
# 108                              Sanjana Karanth  2022-09-04
# 109                               Zarar Khan, AP  2022-09-04
# 110  Acacia Coronado and Adriana Gomez Licon, AP  2022-09-04
# 112                            Marco Margaritoff  2022-09-03
# 114                              Marcia Dunn, AP  2022-09-03
#
# [100 rows x 4 columns]

# %%
kaggle_data = kaggle_data.sample(60000)
pd.set_option('display.max_rows',None)

kaggle_data.to_csv('kaggle_data.csv',index=False)

dataset = pd.read_csv('kaggle_data.csv')

# 977                                       Cole Delbyck  2018-02-07
# 978                                         David Moye  2018-01-25
# 979  Lloyd I. Sederer, MD, ContributorChief Medical...  2017-01-16
# 980                                   Carolyn Gregoire  2015-12-01
# 981  Carolyn O'Donnell, Contributor\nWords with a d...  2012-11-05
# 982                                      Dave Jamieson  2017-11-15
# 983  Nik Bonaddio, ContributorCEO, numberFire.com. ...  2015-01-31
# 984  Pamela Lutrell, ContributorWriter, Blogger, Sp...  2015-06-15
# 985                                     Matthew Jacobs  2017-11-08
# 986                                     Curtis M. Wong  2017-02-08
# 987  Susanna Bair, Contributor\nCo-founder, The Ins...  2013-06-26
# 988  Rep. Earl Blumenauer, ContributorU.S. Represen...  2015-01-09
# 989  John E. Kobara, ContributorExecutive Vice Pres...  2014-12-27
# 990  Ada Polla, ContributorCo-creator, Alchimie For...  2014-11-18
# 991  Brian Dooley, ContributorSenior Advisor, Human...  2017-05-22
# 992  Beth Green, Contributor\nFounder of TheInnerRe...  2014-03-05
# 993                                     Jordan Schultz  2013-02-17
# 994                  Huff TV, Contributor\nContributor  2013-06-06
# 995                                    Erick Fernandez  2015-09-25
# 996                BnBFinder.com, ContributorBnBFinder  2015-04-17
# 997                                           Ed Mazza  2017-10-23
# 998                                    Carly Ledbetter  2016-07-04
# 999                                    Cristian Farias  2016-02-09

# %%
dataset['category'].unique()
# Out:
# array(['HEALTHY LIVING', 'QUEER VOICES', 'ENTERTAINMENT', 'POLITICS',
#        'WORLD NEWS', 'WOMEN', 'DIVORCE', 'SPORTS', 'PARENTS', 'IMPACT',
#        'TECH', 'TASTE', 'THE WORLDPOST', 'WELLNESS', 'GREEN',
#        'LATINO VOICES', 'STYLE & BEAUTY', 'WEIRD NEWS', 'ARTS & CULTURE',
#        'FOOD & DRINK', 'HOME & LIVING', 'RELIGION', 'TRAVEL', 'FIFTY',
#        'MEDIA', 'WORLDPOST', 'BUSINESS', 'BLACK VOICES', 'STYLE',
#        'SCIENCE', 'GOOD NEWS', 'MONEY', 'U.S. NEWS', 'CRIME', 'COMEDY',
#        'WEDDINGS', 'ARTS', 'PARENTING', 'CULTURE & ARTS', 'ENVIRONMENT',
#        'COLLEGE', 'EDUCATION'], dtype=object)

# %%
video_data['Category'].unique()
# Out:
# array(['News & Politics', 'Autos & Vehicles', 'Science & Technology',
#        'Film & Animation', 'Entertainment', 'Howto & Style', 'Education',
#        'Music', 'People & Blogs'], dtype=object)

# %%
category_mapping = {
    "U.S. NEWS": "News & Politics",
    "WORLD NEWS": "News & Politics",
    "POLITICS": "News & Politics",
    "WEIRD NEWS":"News & Politics",
    "CRIME":"News & Politics",
    "COMEDY": "Entertainment",
    "MEDIA":"Entertainment",
    "ENTERTAINMENT": "Entertainment",
    "ARTS & CULTURE": "Entertainment",
    "HOME & LIVING":"People & Blogs",
    "WOMEN":"People & Blogs",
    "PARENTING": "People & Blogs",
    "EDUCATION": "Education",
    "STYLE & BEAUTY": "Howto & Style",
    "SPORTS": "Health & Sports",
    "HEALTHY LIVING": "Health & Sports",
    "WELLNESS": "Health & Sports",
    "FOOD & DRINK": "People & Blogs",
    "BUSINESS": "Business",
    "MONEY": "Business",
    "SCIENCE": "Science & Technology",
    "TRAVEL":"Travel & Events",
    "ENVIRONMENT": "Travel & Events",
    "TECHNOLOGY": "Science & Technology",
    "TECH": "Science & Technology"
}

# Apply the category mapping
kaggle_data["category"] = kaggle_data["category"].map(category_mapping).fillna("Others")

# Count occurrences of each grouped category
category_counts = kaggle_data["category"].value_counts()

# %%
pd.set_option('display.max_columns',None)

kaggle_data = kaggle_data[kaggle_data["category"] != "Others"]

kaggle_data["category"].value_counts()
# Out:
# category
# News & Politics         14479
# Health & Sports          8296
# Entertainment            7912
# People & Blogs           6711
# Travel & Events          3279
# Howto & Style            2744
# Business                 2282
# Science & Technology     1216
# Education                 326
# Name: count, dtype: int64

# %%
kaggle_data.to_csv('kaggle_data.csv')

# %%
kaggle_data["views"] = video_data.groupby("Category")["Views"].transform(lambda x: x.fillna(x.mean()))
kaggle_data["likes"] = video_data.groupby("Category")["Likes"].transform(lambda x: x.fillna(x.mean()))
kaggle_data["comments"] = video_data.groupby("Category")["Comments"].transform(lambda x: x.fillna(x.mean()))

# %%
# Number of videos per category
plt.figure(figsize=(10,6))
plt.style.use('_mpl-gallery-nogrid')


unique_categories = kaggle_data['category'].nunique()
palette = sns.color_palette("Set3", unique_categories) 


sns.countplot(y='category', data=kaggle_data, order=kaggle_data['category'].value_counts().index,palette=palette, hue='category')
plt.title('Number of videos per category')
plt.show()

# %%
video_data['Likes'].fillna(0, inplace=True)  # or video_data['Likes'].fillna(video_data['Likes'].mean(), inplace=True)

# %%
video_data['Category'].fillna("Unknown", inplace=True)

# %%
print("Number of rows in dataset:", len(video_data))
if video_data.empty:
    print("Error: The dataset is empty!")
# Out:
# Number of rows in dataset: 1100

# %%
video_data['Likes'] = pd.to_numeric(video_data['Likes'], errors='coerce')  # Convert to numeric
video_data['Category'] = video_data['Category'].astype(str)  # Ensure it's categorical

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))
video_data.groupby("Category")["Likes"].sum().plot(kind="bar", colormap="viridis")
plt.title("Number of Likes per Category")
plt.xlabel("Category")
plt.ylabel("Total Likes")
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(15, 6))

sns.barplot(x='likes',y='category',data=kaggle_data,palette=palette,hue='category')
# Title and labels
plt.title('Number of Likes per Category')
# Show plot
plt.show()
# Out:
# C:\Users\Abhishek Niraj\anaconda3\Lib\site-packages\seaborn\algorithms.py:98: RuntimeWarning: Mean of empty slice
#   boot_dist.append(f(*sample, **func_kwargs))

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Set figure size
plt.figure(figsize=(15, 6))

# Create bar plot
sns.barplot(x="Likes", y="Category", data=video_data, palette="viridis")

# Title and labels
plt.title("Number of Likes per Category")
plt.xlabel("Likes")
plt.ylabel("Category")

# Show plot
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Load dataset (assuming 'video_data' is already loaded)
plt.figure(figsize=(15, 6))

# Create count plot
sns.countplot(y="Category", data=video_data, order=video_data["Category"].value_counts().index, palette="viridis")

# Title and labels
plt.title("Count of Videos per Category", fontsize=14)
plt.xlabel("Number of Videos")
plt.ylabel("Category")

# Show plot
plt.show()

# %%
video_data["Category"].value_counts().plot(kind="barh", figsize=(12, 6), colormap="viridis")
plt.title("Count of Videos per Category")
plt.xlabel("Number of Videos")
plt.ylabel("Category")
plt.show()
